# %% [markdown]
# # Assignment 4: Hamiltonian Learning of Spin-1/2 Chains
# This code implements a test of the robusness of our training models.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import torch
import torch.nn as nn
import functools
import scipy.linalg

# %% [markdown]
# ## Definiciones

# %%
def kron(args):
    """
    Kronecker product with variable-length arguments.
    """
    backend = np if isinstance(args[0], np.ndarray) else __import__("torch")
    return functools.reduce(backend.kron, args)



# ============================================================
# 0) Pauli matrices y bases de medida
# ============================================================
def paulis():
    I = np.eye(2, dtype=np.complex128)
    X = np.array([[0, 1], [1, 0]], dtype=np.complex128)
    Y = np.array([[0, -1j], [1j, 0]], dtype=np.complex128)
    Z = np.array([[1, 0], [0, -1]], dtype=np.complex128)
    return I, X, Y, Z


def single_qubit_measurement_unitary(axis: int) -> np.ndarray:
    """
    Unitaria que rota la base de medida al eje deseado.
    axis: 0->X, 1->Y, 2->Z
    - Si medimos en X: aplicamos H (Hadamard) y luego medimos en computacional.
    - Si medimos en Y: aplicamos S^† H y luego medimos en computacional.
    - Si medimos en Z: identidad.
    """
    H = np.array([[1, 1], [1, -1]], dtype=np.complex128) / np.sqrt(2)
    Sdg = np.array([[1, 0], [0, -1j]], dtype=np.complex128)  # S^\dagger

    if axis == 0:      # X
        return H
    elif axis == 1:    # Y
        return Sdg @ H
    elif axis == 2:    # Z
        return np.eye(2, dtype=np.complex128)
    else:
        raise ValueError("axis must be 0 (X), 1 (Y), or 2 (Z)")


def rotate_state_for_pauli_measurement(state: np.ndarray, pauli_obs: np.ndarray) -> np.ndarray:
    """
    Aplica U = ⊗_i U_i(pauli_obs[i]) al estado (vector) para convertir
    medición en {X,Y,Z}^n en una medición en la base computacional.

    state: vector (2^n,)
    pauli_obs: array shape (n,), entries in {0,1,2} for X,Y,Z
    """
    n = pauli_obs.shape[0]
   
    U_factors = [single_qubit_measurement_unitary(int(a)) for a in pauli_obs]
    U = kron(U_factors)  
    return U @ state

# %%
# ============================================================
# 1) Apartado 1 (mínimo): elegir Hamiltoniano (Transverse Ising)
#    H = a * sum_i X_i X_{i+1} + b * sum_i Z_i
# ============================================================
def build_richer_hamiltonian_dense(n: int, params: dict) -> np.ndarray:
    """
    Hamiltoniano más complejo (opción 1: más términos):
      H = sum_i [Jxx X_iX_{i+1} + Jyy Y_iY_{i+1} + Jzz Z_iZ_{i+1}]
        + sum_i [hx X_i + hz Z_i]

    params debe contener: {"Jxx","Jyy","Jzz","hx","hz"}
    """
    I, X, Y, Z = paulis()
    dim = 2**n
    H = np.zeros((dim, dim), dtype=np.complex128)

    Jxx = params["Jxx"]
    Jyy = params["Jyy"]
    Jzz = params["Jzz"]
    hx  = params["hx"]
    hz  = params["hz"]

    # Interacciones de vecinos
    for i in range(n - 1):
        ops = [I] * n
        ops[i] = X; ops[i + 1] = X
        H += Jxx * kron(ops)

        ops = [I] * n
        ops[i] = Y; ops[i + 1] = Y
        H += Jyy * kron(ops)

        ops = [I] * n
        ops[i] = Z; ops[i + 1] = Z
        H += Jzz * kron(ops)

    # Campos locales
    for i in range(n):
        ops = [I] * n
        ops[i] = X
        H += hx * kron(ops)

        ops = [I] * n
        ops[i] = Z
        H += hz * kron(ops)

    # Hermiticidad defensiva
    H = 0.5 * (H + H.conj().T)
    return H



# ============================================================
# 2) Apartado 2: generar dataset tipo Algorithm 9
#    - estados iniciales fáciles
#    - tiempos
#    - observables Pauli aleatorios
#    - muestreo (shots) tras rotación a base computacional
# ============================================================
def basis_state(n: int, index: int) -> np.ndarray:
    """|index> en base computacional, como vector (2^n,)."""
    v = np.zeros(2**n, dtype=np.complex128)
    v[index] = 1.0
    return v


def plus_state(n: int) -> np.ndarray:
    """|+>^{⊗n}"""
    v_plus = np.array([1.0, 1.0], dtype=np.complex128) / np.sqrt(2)
    return kron([v_plus] * n)  


def random_product_state(n: int, rng: np.random.Generator) -> np.ndarray:
    """
    Estado producto aleatorio: ⊗_i (cos(theta/2)|0> + e^{i phi} sin(theta/2)|1>)
    """
    vecs = []
    for _ in range(n):
        theta = rng.uniform(0.0, np.pi)
        phi = rng.uniform(0.0, 2 * np.pi)
        v = np.array([np.cos(theta / 2), np.exp(1j * phi) * np.sin(theta / 2)], dtype=np.complex128)
        v = v / np.linalg.norm(v)
        vecs.append(v)
    return kron(vecs)  


def evolve_state_exact(H: np.ndarray, psi0: np.ndarray, t: float) -> np.ndarray:
    """
    Evolución exacta: psi(t) = exp(-i H t) psi0
    """
    U = scipy.linalg.expm(-1j * t * H)
    psi_t = U @ psi0
    # normalización defensiva
    psi_t = psi_t / np.linalg.norm(psi_t)
    return psi_t


def sample_measurements_in_pauli_basis(
    psi_t: np.ndarray,
    pauli_obs: np.ndarray,
    shots: int,
    rng: np.random.Generator
) -> np.ndarray:
    """
    Simula mediciones: rota el estado para medir en la base Pauli dada
    y luego muestrea índices de la base computacional según |amp|^2.

    Devuelve: array shape (shots,) con enteros en [0, 2^n - 1]
    """
    psi_rot = rotate_state_for_pauli_measurement(psi_t, pauli_obs)
    probs = np.abs(psi_rot) ** 2
    probs = probs / probs.sum()
    samples = rng.choice(np.arange(probs.shape[0]), size=shots, p=probs).astype(np.int64)
    return samples


def generate_dataset_algorithm9_style(
    n: int,
    true_params: dict,
    num_initial_states: int = 3,
    num_times: int = 20,
    dt: float = 0.2,
    num_paulis: int = 30,
    shots: int = 200,
    seed: int = 0,
):
    """
    Genera dataset estilo Algorithm 9:
      - initial_states: lista de estados iniciales (vectores)
      - times: array (num_times,)
      - pauli_obs: array (num_paulis, n) con entries 0/1/2 (X/Y/Z)
      - samples: array (S, T, P, shots) con índices en base computacional

    true_params: dict con claves necesarias para construir H.
      Para Transverse Ising: {"a":..., "b":...}
    """
    rng = np.random.default_rng(seed)

    H_true = build_richer_hamiltonian_dense(n=n, params=true_params)

    # --- Estados iniciales (fáciles)
    initial_states = []
    if num_initial_states >= 1:
        initial_states.append(basis_state(n, 0))      # |0...0>
    if num_initial_states >= 2:
        initial_states.append(plus_state(n))          # |+...+>
    while len(initial_states) < num_initial_states:
        initial_states.append(random_product_state(n, rng))

    initial_states = np.stack(initial_states, axis=0)  # (S, 2^n)

    # --- Tiempos
    times = dt * (np.arange(1, num_times + 1))  # (T,)

    # --- Observables Pauli locales aleatorios: 0(X),1(Y),2(Z)
    pauli_obs = rng.integers(0, 3, size=(num_paulis, n), endpoint=False)

    # --- Muestreo
    # samples shape: (S, T, P, shots)
    S = initial_states.shape[0]
    samples = np.empty((S, num_times, num_paulis, shots), dtype=np.int64)

    for s in range(S):
        psi0 = initial_states[s]
        for ti, t in enumerate(times):
            psi_t = evolve_state_exact(H_true, psi0, float(t))
            for p in range(num_paulis):
                samples[s, ti, p, :] = sample_measurements_in_pauli_basis(
                    psi_t=psi_t,
                    pauli_obs=pauli_obs[p],
                    shots=shots,
                    rng=rng
                )

    dataset = {
        "n": n,
        "true_params": true_params,
        "initial_states": initial_states,
        "times": times,
        "pauli_obs": pauli_obs,
        "samples": samples,
    }
    return dataset


def save_dataset_npz(dataset: dict, filename: str = "dataset_part2_algorithm9.npz"):
    """Guardar dataset en NPZ."""
    np.savez_compressed(
        filename,
        n=dataset["n"],
        true_params=str(dataset["true_params"]),
        initial_states=dataset["initial_states"],
        times=dataset["times"],
        pauli_obs=dataset["pauli_obs"],
        samples=dataset["samples"],
    )

# %% [markdown]
# ## Dataset

# %%
n = 4  # número de qubits

true_params = {"Jxx": 0.1, "Jyy": 0.2, "Jzz": 0.7, "hx": 0.3, "hz": 1}
dataset = generate_dataset_algorithm9_style(
    n=n,
    true_params=true_params,
    num_initial_states=3,
    num_times=20,   # recomendado (antes 20)
    dt=0.2,
    num_paulis=30,  # recomendado (antes 30)
    shots=200,      # recomendado (antes 200)
    seed=42,
)

print("initial_states:", dataset["initial_states"].shape)  # (S, 2^n)
print("times:", dataset["times"].shape)                    # (T,)
print("pauli_obs:", dataset["pauli_obs"].shape)            # (P, n)
print("samples:", dataset["samples"].shape)                # (S, T, P, shots)
print("true_params:", dataset["true_params"])

save_dataset_npz(dataset, "dataset_part2_algorithm9_richer.npz")
print("Saved -> dataset_part2_algorithm9_richer.npz")

# ------------------------------------------------------------
# Print dataset "head" (sanity check)
# ------------------------------------------------------------
print("\n=== DATASET HEAD ===")
print("\nInitial state [0] (first 5 amplitudes):")
print(dataset["initial_states"][0][:5])

print("\nTimes (first 5):")
print(dataset["times"][:5])

print("\nPauli observable [0] (0=X, 1=Y, 2=Z):")
print(dataset["pauli_obs"][0])

print("\nSamples [state=0, time=0, pauli=0] (first 10 shots):")
print(dataset["samples"][0, 0, 0, :10])
print("Cada número es un resultado de medición, es decir, un bitstring medido.")
print("Ejemplo: 5 -> '00000101' en binario, lo que significa que se midió |0> en qubits 0,2 y |1> en qubits 1,3,...")
# Out:
# initial_states: (3, 16)
# times: (20,)
# pauli_obs: (30, 4)
# samples: (3, 20, 30, 200)
# true_params: {'Jxx': 0.1, 'Jyy': 0.2, 'Jzz': 0.7, 'hx': 0.3, 'hz': 1}
# Saved -> dataset_part2_algorithm9_richer.npz
#
# === DATASET HEAD ===
#
# Initial state [0] (first 5 amplitudes):
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#
# Times (first 5):
# [0.2 0.4 0.6 0.8 1. ]
#
# Pauli observable [0] (0=X, 1=Y, 2=Z):
# [1 0 2 1]
#
# Samples [state=0, time=0, pauli=0] (first 10 shots):
# [ 0  5  1  5 12  1  0  4  4  9]
# Cada número es un resultado de medición, es decir, un bitstring medido.
# Ejemplo: 5 -> '00000101' en binario, lo que significa que se midió |0> en qubits 0,2 y |1> en qubits 1,3,...

# %% [markdown]
# ## Hamiltoniano

# %%
# ============================================================
# Assignment 4 — Apartado 3
# Ansatz Hamiltonian: Transverse Ising
#
# H_A(c) = c_xx * sum_i X_i X_{i+1} + c_z * sum_i Z_i
# ============================================================

def build_ansatz_hamiltonian_torch(n: int, params: torch.Tensor, device="cpu") -> torch.Tensor:
    """
    H_A =
      Jxx * sum_i X_i X_{i+1}
    + Jyy * sum_i Y_i Y_{i+1}
    + Jzz * sum_i Z_i Z_{i+1}
    + hx  * sum_i X_i
    + hz  * sum_i Z_i

    params: tensor shape (5,) real/complex with zero imaginary part
            [Jxx, Jyy, Jzz, hx, hz]
    """
    Jxx = params[0]
    Jyy = params[1]
    Jzz = params[2]
    hx  = params[3]
    hz  = params[4]

    I, X, Y, Z = paulis_torch(device=device)
    dim = 2**n
    H = torch.zeros((dim, dim), dtype=torch.complex128, device=device)

    # Nearest-neighbour interactions
    for i in range(n - 1):
        ops = [I] * n
        ops[i] = X; ops[i + 1] = X
        H = H + Jxx * kron(ops)

        ops = [I] * n
        ops[i] = Y; ops[i + 1] = Y
        H = H + Jyy * kron(ops)

        ops = [I] * n
        ops[i] = Z; ops[i + 1] = Z
        H = H + Jzz * kron(ops)

    # Local fields
    for i in range(n):
        ops = [I] * n
        ops[i] = X
        H = H + hx * kron(ops)

        ops = [I] * n
        ops[i] = Z
        H = H + hz * kron(ops)

    H = 0.5 * (H + H.conj().T)
    return H

# ============================================================
# Assignment 4 — Apartado 4
# Train a VANILLA Hamiltonian model + visualise results
#
# Vanilla model:
#  - Ansatz Hamiltonian H_A(c) = c_xx * sum_i X_i X_{i+1} + c_z * sum_i Z_i
#  - Exact unitary evolution U(t) = exp(-i H_A t) via eigendecomposition
#  - Likelihood training on Algorithm-9-style measurement samples
#
# We assume you already generated a dataset dict like:
#   dataset = {
#      "n": n,
#      "true_params": {"a":..., "b":...},
#      "initial_states": (S, 2^n) complex numpy,
#      "times": (T,) float numpy,
#      "pauli_obs": (P, n) int numpy with entries 0/1/2 for X/Y/Z,
#      "samples": (S, T, P, shots) int numpy in [0,2^n-1]
#   }
#
# ============================================================

def kron(args):
    """
    Kronecker product with variable-length arguments.
    """
    backend = np if isinstance(args[0], np.ndarray) else torch
    return functools.reduce(backend.kron, args)


# ============================================================
# 1) Pauli matrices (torch) + rotaciones de medida
# ============================================================
def paulis_torch(device="cpu"):
    I = torch.eye(2, dtype=torch.complex128, device=device)
    X = torch.tensor([[0, 1], [1, 0]], dtype=torch.complex128, device=device)
    Y = torch.tensor([[0, -1j], [1j, 0]], dtype=torch.complex128, device=device)
    Z = torch.tensor([[1, 0], [0, -1]], dtype=torch.complex128, device=device)
    return I, X, Y, Z


def single_qubit_measurement_unitary_torch(axis: int, device="cpu") -> torch.Tensor:
    """
    U(axis) rota la base para medir en X/Y/Z mediante medición en computacional.
      axis: 0->X, 1->Y, 2->Z.
    """
    H = torch.tensor([[1, 1], [1, -1]], dtype=torch.complex128, device=device) / np.sqrt(2)
    Sdg = torch.tensor([[1, 0], [0, -1j]], dtype=torch.complex128, device=device)

    if axis == 0:
        return H
    elif axis == 1:
        return Sdg @ H
    elif axis == 2:
        return torch.eye(2, dtype=torch.complex128, device=device)
    else:
        raise ValueError("axis must be 0 (X), 1 (Y), or 2 (Z)")


def build_rotation_operator(pauli_obs_row: np.ndarray, device="cpu") -> torch.Tensor:
    """
    Construye U = ⊗_i U_i(pauli_obs[i]) como matriz (2^n, 2^n).
    pauli_obs_row: shape (n,) int in {0,1,2}
    """
    factors = [single_qubit_measurement_unitary_torch(int(a), device=device) for a in pauli_obs_row]
    return kron(factors) 


# ============================================================
# 2) Ansatz Hamiltonian (torch, diferenciable)
# ============================================================
def build_ansatz_hamiltonian_torch(n: int, params: torch.Tensor, device="cpu") -> torch.Tensor:
    """
    Hamiltoniano ansatz más complejo (5 parámetros):
      H =
        Jxx * sum_i X_i X_{i+1}
      + Jyy * sum_i Y_i Y_{i+1}
      + Jzz * sum_i Z_i Z_{i+1}
      + hx  * sum_i X_i
      + hz  * sum_i Z_i

    params: tensor shape (5,) = [Jxx, Jyy, Jzz, hx, hz]
    """
    Jxx = params[0]
    Jyy = params[1]
    Jzz = params[2]
    hx  = params[3]
    hz  = params[4]

    I, X, Y, Z = paulis_torch(device=device)
    dim = 2**n
    H = torch.zeros((dim, dim), dtype=torch.complex128, device=device)

    # Interacciones vecino a vecino
    for i in range(n - 1):
        ops = [I] * n
        ops[i] = X; ops[i + 1] = X
        H = H + Jxx * kron(ops)

        ops = [I] * n
        ops[i] = Y; ops[i + 1] = Y
        H = H + Jyy * kron(ops)

        ops = [I] * n
        ops[i] = Z; ops[i + 1] = Z
        H = H + Jzz * kron(ops)

    # Campos locales
    for i in range(n):
        ops = [I] * n
        ops[i] = X
        H = H + hx * kron(ops)

        ops = [I] * n
        ops[i] = Z
        H = H + hz * kron(ops)

    H = 0.5 * (H + H.conj().T)
    return H

# ============================================================
# 3) Evolución exacta U(t) psi0 usando eigh (estable + autodiff)
# ============================================================
def evolve_state_matrix_exp(H: torch.Tensor, psi0: torch.Tensor, t: float) -> torch.Tensor:
    """
    psi(t) = exp(-i H t) psi0
    usando exponencial matricial (gradiente bien definido).
    """
    U = torch.matrix_exp((-1j * t) * H)
    psi_t = U @ psi0
    psi_t = psi_t / torch.linalg.norm(psi_t)
    return psi_t

# ============================================================
# 4) Probabilidades para un observable Pauli + samples
# ============================================================
def probs_in_measurement_basis(psi_t: torch.Tensor, Urot: torch.Tensor) -> torch.Tensor:
    """
    Dado psi(t) en base computacional, rota a base de medida:
      psi_rot = Urot @ psi_t
      probs = |psi_rot|^2
    """
    psi_rot = Urot @ psi_t
    probs = torch.abs(psi_rot) ** 2
    probs = probs / torch.sum(probs)
    return probs

# %% [markdown]
# ## Vanilla

# %%
# ============================================================
# 5) Entrenamiento (NLL) — VANILLA (generalizado a 5 parámetros)
#   + Early stopping por "meseta" (si no mejora la NLL)
# ============================================================
def train_vanilla_model(
    dataset: dict,
    num_steps: int = 300,
    lr: float = 5e-2,
    eps: float = 1e-12,
    device: str = "cpu",
    init_params=None,
    verbose: bool = True,
    patience_stop: int = 30,   # nº de iteraciones sin mejorar antes de parar
    min_delta: float = 1e-5,   # mejora mínima exigida en NLL para contar como "mejora"
):
    """
    Minimiza NLL sobre samples:
      NLL = - mean_{s,t,p,shot} log p_theta( sample )

    Versión generalizada para un Hamiltoniano con 5 parámetros:
      params = [Jxx, Jyy, Jzz, hx, hz]

    Early stopping:
      Si la NLL no mejora al menos `min_delta` durante `patience_stop` iteraciones,
      se detiene el entrenamiento antes de llegar a `num_steps`.
    """
    n = int(dataset["n"])
    times = dataset["times"]                 # (T,) numpy
    pauli_obs = dataset["pauli_obs"]         # (P,n) numpy
    samples = dataset["samples"]             # (S,T,P,shots) numpy
    init_states = dataset["initial_states"]  # (S,2^n) numpy complex

    S, T, P, shots = samples.shape
    dim = 2**n

    # Convert initial states to torch
    init_states_t = torch.tensor(init_states, dtype=torch.complex128, device=device)

    # Precompute rotation matrices for each pauli observable row (P of them)
    Urots = []
    for p in range(P):
        Urots.append(build_rotation_operator(pauli_obs[p], device=device))
    Urots = torch.stack(Urots, dim=0)  # (P, dim, dim)

    # ------------------------------------------------------------
    # Parámetros a aprender (5 en la opción 1):
    #   [Jxx, Jyy, Jzz, hx, hz]
    # ------------------------------------------------------------
    if init_params is None:
        init_params = [0.5, 0.5, 0.5, 0.5, 0.5]

    params = torch.nn.Parameter(torch.tensor(init_params, dtype=torch.float64, device=device))
    opt = torch.optim.Adam([params], lr=lr)

    loss_hist = []
    param_hist = []

    # True parameters for plotting (desde dataset)
    true_dict = dataset["true_params"]
    param_names = ["Jxx", "Jyy", "Jzz", "hx", "hz"]
    true_vec = np.array([float(true_dict[k]) for k in param_names], dtype=np.float64)

    # --- NUEVO: estado de early stopping ---
    best_nll = float("inf")
    steps_since_improve = 0

    # Training loop
    for step in range(num_steps):
        opt.zero_grad()

        # Build H(params)
        H = build_ansatz_hamiltonian_torch(n, params.to(torch.complex128), device=device)

        total_logp = torch.tensor(0.0, dtype=torch.float64, device=device)
        count = 0

        for s in range(S):
            psi0 = init_states_t[s]  # (dim,)
            for ti in range(T):
                t = float(times[ti])
                psi_t = evolve_state_matrix_exp(H, psi0, t)

                for p in range(P):
                    probs = probs_in_measurement_basis(psi_t, Urots[p])  # (dim,)
                    idx = torch.tensor(samples[s, ti, p], dtype=torch.long, device=device)  # (shots,)
                    p_samp = probs[idx]  # (shots,)
                    total_logp = total_logp + torch.sum(torch.log(p_samp + eps))
                    count += shots

        nll = -total_logp / count
        nll.backward()
        opt.step()

        nll_val = float(nll.detach().cpu().item())
        loss_hist.append(nll_val)
        param_hist.append(params.detach().cpu().numpy().copy())

        # Print compacto
        cur = param_hist[-1]
        if verbose:
            print(
                f"Step {step+1:4d}/{num_steps} | NLL={nll_val:.6f} | "
                f"Jxx={cur[0]:.4f} (true {true_vec[0]:.4f}) | "
                f"Jyy={cur[1]:.4f} (true {true_vec[1]:.4f}) | "
                f"Jzz={cur[2]:.4f} (true {true_vec[2]:.4f}) | "
                f"hx={cur[3]:.4f} (true {true_vec[3]:.4f}) | "
                f"hz={cur[4]:.4f} (true {true_vec[4]:.4f})"
            )

        # --- NUEVO: early stopping ---
        if nll_val < best_nll - min_delta:
            best_nll = nll_val
            steps_since_improve = 0
        else:
            steps_since_improve += 1

        if steps_since_improve >= patience_stop:
            print(
                f"[EarlyStopping] Parando en step {step+1} porque la NLL no mejora "
                f"(min_delta={min_delta}) en {patience_stop} iteraciones. Best NLL={best_nll:.6f}"
            )
            break
    print(f"Entrenamiento para init:{init_params} finalizado en {step+1} pasos. Mejor NLL={best_nll:.6f}")
    history = {
        "loss": np.array(loss_hist),
        "params": np.array(param_hist),   # (num_steps, 5)
        "true": true_vec,                 # (5,)
        "names": param_names,
    }
    return history


def plot_training(history: dict):
    loss = history["loss"]
    params = history["params"]
    true_vec = history["true"]
    names = history.get("names", [f"p{i}" for i in range(params.shape[1])])

    # Loss
    plt.figure()
    plt.plot(np.arange(len(loss)), loss)
    plt.xlabel("Step")
    plt.ylabel("NLL")
    plt.title("Training loss (NLL)")
    plt.grid(alpha=0.3)
    plt.show()

    # Params (todas las componentes)
    plt.figure()
    steps = np.arange(len(params))
    for k in range(params.shape[1]):
        plt.plot(steps, params[:, k], label=rf"${names[k]}$")
        plt.axhline(true_vec[k], linestyle="--", color=plt.gca().lines[-1].get_color(), alpha=0.7)
    plt.xlabel("Step")
    plt.ylabel("Parameter value")
    plt.title("Learned Hamiltonian parameters (vanilla)")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()


# ============================================================
# Example usage:
# ============================================================
'''init_params = np.random.uniform(0, 1, size=5)
#init_params = [5.0, -4.0, 3.5, -2.0, 4.0]
history = train_vanilla_model(dataset, num_steps=500, lr=0.01,  device="cpu", init_params=init_params, patience_stop=50, min_delta=1e-5)
plot_training(history)'''
# Out:
# 'init_params = np.random.uniform(0, 1, size=5)\n#init_params = [5.0, -4.0, 3.5, -2.0, 4.0]\nhistory = train_vanilla_model(dataset, num_steps=500, lr=0.01,  device="cpu", init_params=init_params, patience_stop=50, min_delta=1e-5)\nplot_training(history)'

# %% [markdown]
# ## robustness

# %%
def relative_param_error(theta_hat: np.ndarray, theta_true: np.ndarray, eps: float = 1e-12) -> float:
    """
    Error relativo tipo paper:
        ||theta_hat - theta_true||_1 / (||theta_true||_1 + eps)
    """
    num = np.linalg.norm(theta_hat - theta_true, ord=1)
    den = np.linalg.norm(theta_true, ord=1) + eps
    return float(num / den)

def robustness_study_vanilla(
    dataset: dict,
    n_runs: int = 20,
    init_low: float = -0.2,
    init_high: float = 1.2,
    success_threshold: float = 0.1,   # típico (paper usa 0.1)
    num_steps: int = 500,
    lr: float = 0.05,
    device: str = "cpu",
    patience_stop: int = 30,
    min_delta: float = 1e-5,
    seed: int = 0,
    verbose_each_run: bool = False,
):
    """
    Repite el entrenamiento n_runs veces con distintas inicializaciones.
    Devuelve errores finales, NLL finales, parámetros finales y success rate.
    """
    rng = np.random.default_rng(seed)

    errors = []
    final_nll = []
    final_params = []
    steps_used = []

    for r in range(n_runs):
        init_params = rng.uniform(init_low, init_high, size=5)

        hist = train_vanilla_model(
            dataset,
            num_steps=num_steps,
            lr=lr,
            device=device,
            init_params=init_params,
            patience_stop=patience_stop,
            min_delta=min_delta,
            verbose=verbose_each_run,
        )

        theta_true = hist["true"]
        theta_hat = hist["params"][-1]          # último valor aprendido
        nll_last = hist["loss"][-1]             # última NLL
        steps_last = len(hist["loss"])

        err = relative_param_error(theta_hat, theta_true)

        errors.append(err)
        final_nll.append(float(nll_last))
        final_params.append(theta_hat.copy())
        steps_used.append(steps_last)

        if not verbose_each_run:
            print(f"Run {r+1:02d}/{n_runs} | steps={steps_last:4d} | NLL={nll_last:.5f} | rel.err={err:.4f}")

    errors = np.array(errors)
    final_nll = np.array(final_nll)
    final_params = np.array(final_params)
    steps_used = np.array(steps_used)

    success = errors < success_threshold
    success_rate = float(np.mean(success))

    results = {
        "errors": errors,
        "final_nll": final_nll,
        "final_params": final_params,
        "steps_used": steps_used,
        "success": success,
        "success_threshold": success_threshold,
        "success_rate": success_rate,
    }
    return results

def plot_robustness_hist(results: dict, bins: int = 12, title_prefix: str = "Vanilla"):
    errors = results["errors"]
    thr = results["success_threshold"]
    success_rate = results["success_rate"]

    plt.figure()
    plt.hist(errors, bins=bins)
    plt.axvline(thr, linestyle="--", linewidth=2, label=f"success threshold = {thr}")
    plt.xlabel(r"Relative parameter error  $\|\hat\theta-\theta\|_1 / \|\theta\|_1$")
    plt.ylabel("Count")
    plt.title(f"{title_prefix} robustness: error distribution\nsuccess rate = {success_rate*100:.1f}%")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()

    # (Opcional) histograma de NLL final
    plt.figure()
    plt.hist(results["final_nll"], bins=bins)
    plt.xlabel("Final NLL")
    plt.ylabel("Count")
    plt.title(f"{title_prefix} robustness: final NLL distribution")
    plt.grid(alpha=0.3)
    plt.show()

# ============================================================
# Example robustness study:
# ============================================================

rob = robustness_study_vanilla(
    dataset,
    n_runs=20,
    init_low=0.1,
    init_high=1,
    success_threshold=0.1,
    num_steps=500,
    lr=0.01,
    device="cpu",
    patience_stop=30,
    min_delta=1e-5,
    seed=123,
    verbose_each_run=False,   # pon True si quieres ver prints dentro de cada run
)


plot_robustness_hist(rob, bins=10, title_prefix="Vanilla")
print("Success rate:", rob["success_rate"])
print("Errors (mean ± std):", rob["errors"].mean(), "±", rob["errors"].std())
# Out:
# [EarlyStopping] Parando en step 219 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069595
# Entrenamiento para init:[0.71411668 0.14843892 0.29832389 0.26593463 0.25831531] finalizado en 219 pasos. Mejor NLL=2.069595
# Run 01/20 | steps= 219 | NLL=2.06959 | rel.err=0.0023
# [EarlyStopping] Parando en step 266 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.651204
# Entrenamiento para init:[0.83088506 0.9310105  0.34891696 0.83777911 0.90090342] finalizado en 266 pasos. Mejor NLL=2.651204
# Run 02/20 | steps= 266 | NLL=2.65120 | rel.err=0.7212
# [EarlyStopping] Parando en step 147 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069602
# Entrenamiento para init:[0.56167341 0.32046814 0.84181744 0.29238667 0.76732035] finalizado en 147 pasos. Mejor NLL=2.069602
# Run 03/20 | steps= 147 | NLL=2.06959 | rel.err=0.0024
# [EarlyStopping] Parando en step 230 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.651564
# Entrenamiento para init:[0.66694618 0.93466653 0.30871737 0.81921262 0.56634853] finalizado en 230 pasos. Mejor NLL=2.651564
# Run 04/20 | steps= 230 | NLL=2.65156 | rel.err=0.6597
# [EarlyStopping] Parando en step 205 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069595
# Entrenamiento para init:[0.30840006 0.24931359 0.54801007 0.62445218 0.26590419] finalizado en 205 pasos. Mejor NLL=2.069595
# Run 05/20 | steps= 205 | NLL=2.06959 | rel.err=0.0020
# [EarlyStopping] Parando en step 161 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069599
# Entrenamiento para init:[0.11340543 0.52401991 0.755419   0.92674044 0.66298061] finalizado en 161 pasos. Mejor NLL=2.069599
# Run 06/20 | steps= 161 | NLL=2.06959 | rel.err=0.0020
# [EarlyStopping] Parando en step 204 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.655108
# Entrenamiento para init:[0.92541032 0.87822123 0.29632859 0.87951469 0.75767674] finalizado en 204 pasos. Mejor NLL=2.655108
# Run 07/20 | steps= 204 | NLL=2.65510 | rel.err=0.7233
# [EarlyStopping] Parando en step 175 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069598
# Entrenamiento para init:[0.35007876 0.8173392  0.87869954 0.36949411 0.57433788] finalizado en 175 pasos. Mejor NLL=2.069598
# Run 08/20 | steps= 175 | NLL=2.06959 | rel.err=0.0018
# [EarlyStopping] Parando en step 195 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069596
# Entrenamiento para init:[0.16433813 0.62491457 0.31411576 0.78846728 0.25626847] finalizado en 195 pasos. Mejor NLL=2.069596
# Run 09/20 | steps= 195 | NLL=2.06959 | rel.err=0.0019
# [EarlyStopping] Parando en step 168 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069597
# Entrenamiento para init:[0.38146803 0.11302703 0.12929673 0.54703166 0.52148128] finalizado en 168 pasos. Mejor NLL=2.069597
# Run 10/20 | steps= 168 | NLL=2.06959 | rel.err=0.0020
# [EarlyStopping] Parando en step 117 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.603588
# Entrenamiento para init:[0.21492129 0.33180625 0.102863   0.44296097 0.61828578] finalizado en 117 pasos. Mejor NLL=2.603588
# Run 11/20 | steps= 117 | NLL=2.60359 | rel.err=0.4646
# [EarlyStopping] Parando en step 121 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.651567
# Entrenamiento para init:[0.48456889 0.85159211 0.65484213 0.33947552 0.8299199 ] finalizado en 121 pasos. Mejor NLL=2.651567
# Run 12/20 | steps= 121 | NLL=2.65156 | rel.err=0.6597
# [EarlyStopping] Parando en step 181 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069599
# Entrenamiento para init:[0.54953808 0.78292929 0.60948018 0.49369633 0.456539  ] finalizado en 181 pasos. Mejor NLL=2.069599
# Run 13/20 | steps= 181 | NLL=2.06959 | rel.err=0.0021
# [EarlyStopping] Parando en step 172 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069603
# Entrenamiento para init:[0.12001176 0.52241571 0.66120256 0.95150208 0.49179347] finalizado en 172 pasos. Mejor NLL=2.069603
# Run 14/20 | steps= 172 | NLL=2.06959 | rel.err=0.0019
# [EarlyStopping] Parando en step 364 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069597
# Entrenamiento para init:[0.53707726 0.56720363 0.46773188 0.62091615 0.16331561] finalizado en 364 pasos. Mejor NLL=2.069597
# Run 15/20 | steps= 364 | NLL=2.06959 | rel.err=0.0023
# [EarlyStopping] Parando en step 205 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069595
# Entrenamiento para init:[0.53954545 0.64913035 0.7694912  0.48684729 0.37252192] finalizado en 205 pasos. Mejor NLL=2.069595
# Run 16/20 | steps= 205 | NLL=2.06959 | rel.err=0.0022
# [EarlyStopping] Parando en step 177 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.069597
# Entrenamiento para init:[0.10530103 0.78083107 0.16981837 0.54098923 0.37392499] finalizado en 177 pasos. Mejor NLL=2.069597
# Run 17/20 | steps= 177 | NLL=2.06959 | rel.err=0.0020
# [EarlyStopping] Parando en step 252 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.654623
# Entrenamiento para init:[0.85673995 0.95542828 0.38698712 0.90799146 0.40377615] finalizado en 252 pasos. Mejor NLL=2.654623
# Run 18/20 | steps= 252 | NLL=2.65462 | rel.err=0.6636
# [EarlyStopping] Parando en step 141 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.730605
# Entrenamiento para init:[0.8309009  0.81895924 0.68975666 0.30583311 0.22390702] finalizado en 141 pasos. Mejor NLL=2.730605
# Run 19/20 | steps= 141 | NLL=2.73060 | rel.err=0.9513
# [EarlyStopping] Parando en step 267 porque la NLL no mejora (min_delta=1e-05) en 30 iteraciones. Best NLL=2.709226
# Entrenamiento para init:[0.48193403 0.23638488 0.88594565 0.26121408 0.1272652 ] finalizado en 267 pasos. Mejor NLL=2.709226
# Run 20/20 | steps= 267 | NLL=2.70922 | rel.err=0.8645
# Success rate: 0.6
# Errors (mean ± std): 0.2866498453999257 ± 0.3591042947898041

# %%
# save data for later analysis
#time 23 min
with open("robustness_vanilla.pkl", "wb") as f:
    pickle.dump(rob, f)

# %%
with open("robustness_vanilla.pkl", "rb") as f:
    loaded_rob = pickle.load(f)
print("Loaded robustness data keys:", loaded_rob.keys())
print("Loaded success rate:", loaded_rob["success_rate"])
print("Loaded errors (mean ± std):", loaded_rob["errors"].mean(), "±", loaded_rob["errors"].std())
plot_robustness_hist(loaded_rob, bins=15, title_prefix="Vanilla (loaded)")
# Out:
# Loaded robustness data keys: dict_keys(['errors', 'final_nll', 'final_params', 'steps_used', 'success', 'success_threshold', 'success_rate'])
# Loaded success rate: 0.6
# Loaded errors (mean ± std): 0.2866498453999257 ± 0.3591042947898041

# %% [markdown]
# ## Neural ODE

# %%
# ============================================================
# CAMBIOS:
# 1) RK4: eliminada normalización dentro de rk4_step.
#    La normalización se aplica SOLO al guardar estados (integrate_ode_rk4).
# 2) Integración: añadimos m substeps por intervalo para mayor precisión.
# 3) CoeffNet: pasa de R^2 -> R^2 a R^5 -> R^5 (para [Jxx,Jyy,Jzz,hx,hz]).
# 4) Plot: grafica c_eff (parámetros efectivos usados en el Hamiltoniano).
# ============================================================

# ============================================================
# Neural ODE: RK4 integrator for Schrödinger equation
# dpsi/dt = -i H psi
# ============================================================
def rk4_step(psi, dt, H):
    # RK4 step WITHOUT renormalizing inside the integrator
    k1 = (-1j) * (H @ psi)
    k2 = (-1j) * (H @ (psi + 0.5 * dt * k1))
    k3 = (-1j) * (H @ (psi + 0.5 * dt * k2))
    k4 = (-1j) * (H @ (psi + dt * k3))
    psi_next = psi + (dt / 6.0) * (k1 + 2*k2 + 2*k3 + k4)
    return psi_next


def integrate_ode_rk4(psi0, times_torch, H, m=20):
    """
    Integrate from t=0 to each time in times_torch using RK4 with m substeps.
    Normalization is applied only when storing psi(t_k), not inside RK4.
    """
    states = []
    t_prev = 0.0
    psi = psi0

    for t in times_torch:
        t_target = float(t.item())
        dt_big = t_target - t_prev
        dt = dt_big / m

        for _ in range(m):
            psi = rk4_step(psi, dt, H)
            t_prev += dt

        # normalize once per observation time (numerical stability)
        psi = psi / torch.linalg.norm(psi)
        states.append(psi)

    return torch.stack(states, dim=0)  # (T, dim)

def integrate_ode_rk4_time_dependent(psi0, times_torch, c, net, n, device, dc_scale=0.2, m=20):
    states = []
    t_prev = torch.tensor(0.0, dtype=torch.float64, device=device)
    psi = psi0

    for t in times_torch:
        t_target = t.to(torch.float64)
        dt_big = t_target - t_prev
        dt = dt_big / m

        for _ in range(m):
            # c_eff(t_prev)
            dc = dc_scale * net(c, t_prev)
            c_eff = c + dc

            H = build_ansatz_hamiltonian_torch(
                n, c_eff.to(torch.complex128), device=device
            )

            psi = rk4_step(psi, float(dt.item()), H)
            t_prev = t_prev + dt

        psi = psi / torch.linalg.norm(psi)
        states.append(psi)

    return torch.stack(states, dim=0)
# ============================================================
# Neural map NN_phi on coefficients: R^5 -> R^5
# params = [Jxx, Jyy, Jzz, hx, hz]
# ============================================================
class CoeffNetT(nn.Module):
    def __init__(self, hidden=32, dim_params=5):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim_params + 1, hidden),
            nn.Tanh(),
            nn.Linear(hidden, hidden),
            nn.Tanh(),
            nn.Linear(hidden, dim_params),
        )

    def forward(self, c, t):
        # c: (5,), t: float tensor ()
        x = torch.cat([c, t.view(1)], dim=0)
        return self.net(x)


def plot_training_nde_eff(history: dict):

    loss = history["loss"]
    c_eff = history["c_eff"]
    true_vec = history["true"]
    names = history.get("names", [f"p{i}" for i in range(c_eff.shape[1])])

    # Loss
    plt.figure()
    plt.plot(np.arange(len(loss)), loss)
    plt.xlabel("Step")
    plt.ylabel("NLL")
    plt.title("Training loss (Neural ODE)")
    plt.grid(alpha=0.3)
    plt.show()

    # Params efectivos
    plt.figure()
    steps = np.arange(len(c_eff))
    for k in range(c_eff.shape[1]):
        plt.plot(steps, c_eff[:, k], label=rf"${names[k]}^{{eff}}$")
        plt.axhline(true_vec[k], linestyle="--", color=plt.gca().lines[-1].get_color(), alpha=0.7)

    plt.xlabel("Step")
    plt.ylabel("Parameter value")
    plt.title("Learned Hamiltonian parameters (effective)")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

def plot_training_nde_eff(history: dict):

torch.set_default_dtype(torch.float64)
    loss = history["loss"]
    c_eff = history["c_eff"]
    true_vec = history["true"]
    names = history.get("names", [f"p{i}" for i in range(c_eff.shape[1])])

    # Loss
    plt.figure()
    plt.plot(np.arange(len(loss)), loss)
    plt.xlabel("Step")
    plt.ylabel("NLL")
    plt.title("Training loss (Neural ODE)")
    plt.grid(alpha=0.3)
    plt.show()

    # Params efectivos
    plt.figure()
    steps = np.arange(len(c_eff))
    for k in range(c_eff.shape[1]):
        plt.plot(steps, c_eff[:, k], label=rf"${names[k]}^{{eff}}$")
        plt.axhline(true_vec[k], linestyle="--", color=plt.gca().lines[-1].get_color(), alpha=0.7)

    plt.xlabel("Step")
    plt.ylabel("Parameter value")
    plt.title("Learned Hamiltonian parameters (effective)")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

# %% [markdown]
# ## Entrenamientos

# %%
# ============================================================
# PEGAR TAL CUAL (arreglado):
# - Usa CoeffNetT(c,t) correctamente
# - NO calcula dc/net(c) fuera (eso daba error y además no sirve con H(t))
# - Regularización evaluada en 3 tiempos (0, medio, final)
# - Guarda c_eff en t=0 para el plot (y opcionalmente en t=T)
# REQUIERE que tengas definidas:
#   - CoeffNetT (la red con forward(self, c, t))
#   - integrate_ode_rk4_time_dependent (la que construye H dentro del integrador)
#   - build_ansatz_hamiltonian_torch, build_rotation_operator, probs_in_measurement_basis
# ============================================================

def train_neural_ode_model(
    dataset: dict,
    num_steps: int = 300,
    lr: float = 5e-2,
    eps: float = 1e-12,
    device: str = "cpu",
    hidden: int = 32,
    dc_scale: float = 0.05,
    m: int = 20,
    regularization: float = 0.001,
    init: list = None,

    # early stopping
    patience_stop: int = 50,
    min_delta: float = 1e-5,
    everbose: bool = True,
):


    n = int(dataset["n"])
    times = torch.tensor(dataset["times"], dtype=torch.float64, device=device)  # (T,)
    pauli_obs = dataset["pauli_obs"]         # numpy (P,n)
    samples = dataset["samples"]             # numpy (S,T,P,shots)
    init_states = dataset["initial_states"]  # numpy (S,2^n) complex

    S, T, P, shots = samples.shape
    dim = 2**n

    # initial states to torch complex
    init_states_t = torch.tensor(init_states, dtype=torch.complex128, device=device)

    # precompute rotation matrices
    Urots = []
    for p in range(P):
        Urots.append(build_rotation_operator(pauli_obs[p], device=device))
    Urots = torch.stack(Urots, dim=0)  # (P, dim, dim)

    # ------------------------------------------------------------
    # Parámetros a aprender (5): [Jxx, Jyy, Jzz, hx, hz]
    # ------------------------------------------------------------
    dim_params = 5
    if init is None:
        init = [0.5] * dim_params
    assert len(init) == dim_params, f"`init` debe tener longitud {dim_params}"

    c = nn.Parameter(torch.tensor(init, dtype=torch.float64, device=device))

    # Red con tiempo: forward(c, t) -> R^5
    net = CoeffNetT(hidden=hidden, dim_params=dim_params).to(device)

    opt = torch.optim.Adam(list(net.parameters()) + [c], lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        opt, mode="min", factor=0.5, patience=20, min_lr=1e-4
    )

    # True parameters (desde dataset)
    true_dict = dataset["true_params"]
    param_names = ["Jxx", "Jyy", "Jzz", "hx", "hz"]
    true_vec = np.array([float(true_dict[k]) for k in param_names], dtype=np.float64)

    loss_hist = []
    c_hist = []
    dc_hist = []
    c_eff_hist = []

    # early stopping state
    best_loss = float("inf")
    steps_since_improve = 0

    # tiempos para regularización y logging
    t0 = torch.tensor(0.0, dtype=torch.float64, device=device)
    tmid = times[len(times)//2]
    tT = times[-1]

    for step in range(num_steps):
        opt.zero_grad()

        total_logp = torch.tensor(0.0, dtype=torch.float64, device=device)
        count = 0

        for s in range(S):
            psi0 = init_states_t[s]  # (dim,)
            psi_ts = integrate_ode_rk4_time_dependent(
                psi0, times, c, net, n, device=device, dc_scale=dc_scale, m=m
            )  # (T, dim)

            for ti in range(T):
                psi_t = psi_ts[ti]
                for p in range(P):
                    probs = probs_in_measurement_basis(psi_t, Urots[p])
                    idx = torch.tensor(samples[s, ti, p], dtype=torch.long, device=device)
                    p_samp = probs[idx]
                    total_logp = total_logp + torch.sum(torch.log(p_samp + eps))
                    count += shots

        nll = -total_logp / count

        # Regularización: penaliza tamaño de dc en varios tiempos
        dc0 = dc_scale * net(c, t0)
        dcm = dc_scale * net(c, tmid)
        dcT = dc_scale * net(c, tT)
        reg = regularization * (dc0.pow(2).sum() + dcm.pow(2).sum() + dcT.pow(2).sum()) / 3.0

        loss = nll + reg
        loss.backward()
        opt.step()

        loss_val = float(loss.detach().cpu().item())
        loss_hist.append(loss_val)

        # logging/plots: guardamos c, dc(t=0) y c_eff(t=0)
        with torch.no_grad():
            dc_log = (dc_scale * net(c, t0)).detach()
            c_eff_log = (c + dc_log).detach()

        c_hist.append(c.detach().cpu().numpy().copy())
        dc_hist.append(dc_log.cpu().numpy().copy())
        c_eff_hist.append(c_eff_log.cpu().numpy().copy())

        cur_eff = c_eff_hist[-1]
        if everbose:
            print(
                f"[NDE(t)] Step {step+1:4d}/{num_steps} | Loss={loss_val:.6f} | "
                f"Jxx_eff={cur_eff[0]:.4f} (true {true_vec[0]:.4f}) | "
                f"Jyy_eff={cur_eff[1]:.4f} (true {true_vec[1]:.4f}) | "
                f"Jzz_eff={cur_eff[2]:.4f} (true {true_vec[2]:.4f}) | "
                f"hx_eff={cur_eff[3]:.4f} (true {true_vec[3]:.4f}) | "
                f"hz_eff={cur_eff[4]:.4f} (true {true_vec[4]:.4f})"
            )

        scheduler.step(loss.detach())

        # Early stopping
        if loss_val < best_loss - min_delta:
            best_loss = loss_val
            steps_since_improve = 0
        else:
            steps_since_improve += 1

        if steps_since_improve >= patience_stop:
            print(
                f"[EarlyStopping] Parando en step {step+1} porque la loss no mejora "
                f"(min_delta={min_delta}) en {patience_stop} iteraciones. Best={best_loss:.6f}"
            )
            break

    history = {
        "loss": np.array(loss_hist),
        "c": np.array(c_hist),
        "dc": np.array(dc_hist),
        "c_eff": np.array(c_eff_hist),
        "true": true_vec,
        "names": param_names,
    }
    return history


# ==========================
# EJEMPLO DE EJECUCIÓN
# ==========================
init_params = np.random.uniform(0, 1, size=5)


history_nde_modificado = train_neural_ode_model(
    dataset,
    num_steps=300,
    lr=0.01,
    hidden=32,
    dc_scale=0.2,
    m=30, 
    regularization=0.001,
    init=init_params,
    patience_stop=50,
    min_delta=1e-5
)

plot_training_nde_eff(history_nde_modificado)
# Out:
# [NDE(t)] Step    1/300 | Loss=2.528144 | Jxx_eff=0.1816 (true 0.1000) | Jyy_eff=0.2423 (true 0.2000) | Jzz_eff=0.9256 (true 0.7000) | hx_eff=0.1079 (true 0.3000) | hz_eff=0.7320 (true 1.0000)
# [NDE(t)] Step    2/300 | Loss=2.473012 | Jxx_eff=0.1563 (true 0.1000) | Jyy_eff=0.2010 (true 0.2000) | Jzz_eff=0.9097 (true 0.7000) | hx_eff=0.1820 (true 0.3000) | hz_eff=0.7770 (true 1.0000)
# [NDE(t)] Step    3/300 | Loss=2.454202 | Jxx_eff=0.1518 (true 0.1000) | Jyy_eff=0.1911 (true 0.2000) | Jzz_eff=0.8590 (true 0.7000) | hx_eff=0.2239 (true 0.3000) | hz_eff=0.7986 (true 1.0000)
# [NDE(t)] Step    4/300 | Loss=2.423677 | Jxx_eff=0.1588 (true 0.1000) | Jyy_eff=0.1872 (true 0.2000) | Jzz_eff=0.8079 (true 0.7000) | hx_eff=0.2529 (true 0.3000) | hz_eff=0.8380 (true 1.0000)
# [NDE(t)] Step    5/300 | Loss=2.359584 | Jxx_eff=0.1638 (true 0.1000) | Jyy_eff=0.1787 (true 0.2000) | Jzz_eff=0.7520 (true 0.7000) | hx_eff=0.2731 (true 0.3000) | hz_eff=0.8926 (true 1.0000)
# [NDE(t)] Step    6/300 | Loss=2.249112 | Jxx_eff=0.1482 (true 0.1000) | Jyy_eff=0.1588 (true 0.2000) | Jzz_eff=0.6927 (true 0.7000) | hx_eff=0.2896 (true 0.3000) | hz_eff=0.9579 (true 1.0000)
# [NDE(t)] Step    7/300 | Loss=2.133285 | Jxx_eff=0.1203 (true 0.1000) | Jyy_eff=0.1321 (true 0.2000) | Jzz_eff=0.6353 (true 0.7000) | hx_eff=0.3068 (true 0.3000) | hz_eff=1.0305 (true 1.0000)
# [NDE(t)] Step    8/300 | Loss=2.091516 | Jxx_eff=0.0953 (true 0.1000) | Jyy_eff=0.1171 (true 0.2000) | Jzz_eff=0.6110 (true 0.7000) | hx_eff=0.3233 (true 0.3000) | hz_eff=1.0962 (true 1.0000)
# [NDE(t)] Step    9/300 | Loss=2.150008 | Jxx_eff=0.0983 (true 0.1000) | Jyy_eff=0.1293 (true 0.2000) | Jzz_eff=0.6192 (true 0.7000) | hx_eff=0.3339 (true 0.3000) | hz_eff=1.1266 (true 1.0000)
# [NDE(t)] Step   10/300 | Loss=2.173142 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1495 (true 0.2000) | Jzz_eff=0.6418 (true 0.7000) | hx_eff=0.3372 (true 0.3000) | hz_eff=1.1317 (true 1.0000)
# [NDE(t)] Step   11/300 | Loss=2.157967 | Jxx_eff=0.1296 (true 0.1000) | Jyy_eff=0.1745 (true 0.2000) | Jzz_eff=0.6706 (true 0.7000) | hx_eff=0.3315 (true 0.3000) | hz_eff=1.1164 (true 1.0000)
# [NDE(t)] Step   12/300 | Loss=2.123879 | Jxx_eff=0.1429 (true 0.1000) | Jyy_eff=0.1951 (true 0.2000) | Jzz_eff=0.6992 (true 0.7000) | hx_eff=0.3199 (true 0.3000) | hz_eff=1.0888 (true 1.0000)
# [NDE(t)] Step   13/300 | Loss=2.099122 | Jxx_eff=0.1412 (true 0.1000) | Jyy_eff=0.2038 (true 0.2000) | Jzz_eff=0.7218 (true 0.7000) | hx_eff=0.3060 (true 0.3000) | hz_eff=1.0554 (true 1.0000)
# [NDE(t)] Step   14/300 | Loss=2.089055 | Jxx_eff=0.1288 (true 0.1000) | Jyy_eff=0.2021 (true 0.2000) | Jzz_eff=0.7358 (true 0.7000) | hx_eff=0.2944 (true 0.3000) | hz_eff=1.0229 (true 1.0000)
# [NDE(t)] Step   15/300 | Loss=2.090824 | Jxx_eff=0.1111 (true 0.1000) | Jyy_eff=0.1953 (true 0.2000) | Jzz_eff=0.7408 (true 0.7000) | hx_eff=0.2865 (true 0.3000) | hz_eff=0.9961 (true 1.0000)
# [NDE(t)] Step   16/300 | Loss=2.099457 | Jxx_eff=0.0928 (true 0.1000) | Jyy_eff=0.1888 (true 0.2000) | Jzz_eff=0.7378 (true 0.7000) | hx_eff=0.2830 (true 0.3000) | hz_eff=0.9782 (true 1.0000)
# [NDE(t)] Step   17/300 | Loss=2.107356 | Jxx_eff=0.0778 (true 0.1000) | Jyy_eff=0.1859 (true 0.2000) | Jzz_eff=0.7286 (true 0.7000) | hx_eff=0.2835 (true 0.3000) | hz_eff=0.9703 (true 1.0000)
# [NDE(t)] Step   18/300 | Loss=2.108814 | Jxx_eff=0.0691 (true 0.1000) | Jyy_eff=0.1886 (true 0.2000) | Jzz_eff=0.7156 (true 0.7000) | hx_eff=0.2871 (true 0.3000) | hz_eff=0.9718 (true 1.0000)
# [NDE(t)] Step   19/300 | Loss=2.102198 | Jxx_eff=0.0675 (true 0.1000) | Jyy_eff=0.1973 (true 0.2000) | Jzz_eff=0.7017 (true 0.7000) | hx_eff=0.2930 (true 0.3000) | hz_eff=0.9810 (true 1.0000)
# [NDE(t)] Step   20/300 | Loss=2.090892 | Jxx_eff=0.0723 (true 0.1000) | Jyy_eff=0.2101 (true 0.2000) | Jzz_eff=0.6894 (true 0.7000) | hx_eff=0.2994 (true 0.3000) | hz_eff=0.9957 (true 1.0000)
# [NDE(t)] Step   21/300 | Loss=2.081086 | Jxx_eff=0.0809 (true 0.1000) | Jyy_eff=0.2240 (true 0.2000) | Jzz_eff=0.6815 (true 0.7000) | hx_eff=0.3055 (true 0.3000) | hz_eff=1.0130 (true 1.0000)
# [NDE(t)] Step   22/300 | Loss=2.077443 | Jxx_eff=0.0912 (true 0.1000) | Jyy_eff=0.2356 (true 0.2000) | Jzz_eff=0.6797 (true 0.7000) | hx_eff=0.3100 (true 0.3000) | hz_eff=1.0299 (true 1.0000)
# [NDE(t)] Step   23/300 | Loss=2.079419 | Jxx_eff=0.1004 (true 0.1000) | Jyy_eff=0.2419 (true 0.2000) | Jzz_eff=0.6837 (true 0.7000) | hx_eff=0.3115 (true 0.3000) | hz_eff=1.0437 (true 1.0000)
# [NDE(t)] Step   24/300 | Loss=2.083639 | Jxx_eff=0.1067 (true 0.1000) | Jyy_eff=0.2413 (true 0.2000) | Jzz_eff=0.6921 (true 0.7000) | hx_eff=0.3098 (true 0.3000) | hz_eff=1.0522 (true 1.0000)
# [NDE(t)] Step   25/300 | Loss=2.086376 | Jxx_eff=0.1098 (true 0.1000) | Jyy_eff=0.2342 (true 0.2000) | Jzz_eff=0.7026 (true 0.7000) | hx_eff=0.3053 (true 0.3000) | hz_eff=1.0542 (true 1.0000)
# [NDE(t)] Step   26/300 | Loss=2.085734 | Jxx_eff=0.1106 (true 0.1000) | Jyy_eff=0.2224 (true 0.2000) | Jzz_eff=0.7127 (true 0.7000) | hx_eff=0.2992 (true 0.3000) | hz_eff=1.0497 (true 1.0000)
# [NDE(t)] Step   27/300 | Loss=2.082225 | Jxx_eff=0.1111 (true 0.1000) | Jyy_eff=0.2083 (true 0.2000) | Jzz_eff=0.7207 (true 0.7000) | hx_eff=0.2930 (true 0.3000) | hz_eff=1.0394 (true 1.0000)
# [NDE(t)] Step   28/300 | Loss=2.077665 | Jxx_eff=0.1126 (true 0.1000) | Jyy_eff=0.1943 (true 0.2000) | Jzz_eff=0.7252 (true 0.7000) | hx_eff=0.2884 (true 0.3000) | hz_eff=1.0254 (true 1.0000)
# [NDE(t)] Step   29/300 | Loss=2.074023 | Jxx_eff=0.1158 (true 0.1000) | Jyy_eff=0.1824 (true 0.2000) | Jzz_eff=0.7257 (true 0.7000) | hx_eff=0.2863 (true 0.3000) | hz_eff=1.0098 (true 1.0000)
# [NDE(t)] Step   30/300 | Loss=2.072401 | Jxx_eff=0.1207 (true 0.1000) | Jyy_eff=0.1735 (true 0.2000) | Jzz_eff=0.7228 (true 0.7000) | hx_eff=0.2869 (true 0.3000) | hz_eff=0.9949 (true 1.0000)
# [NDE(t)] Step   31/300 | Loss=2.072991 | Jxx_eff=0.1263 (true 0.1000) | Jyy_eff=0.1679 (true 0.2000) | Jzz_eff=0.7175 (true 0.7000) | hx_eff=0.2896 (true 0.3000) | hz_eff=0.9831 (true 1.0000)
# [NDE(t)] Step   32/300 | Loss=2.074970 | Jxx_eff=0.1313 (true 0.1000) | Jyy_eff=0.1653 (true 0.2000) | Jzz_eff=0.7112 (true 0.7000) | hx_eff=0.2933 (true 0.3000) | hz_eff=0.9757 (true 1.0000)
# [NDE(t)] Step   33/300 | Loss=2.076836 | Jxx_eff=0.1348 (true 0.1000) | Jyy_eff=0.1649 (true 0.2000) | Jzz_eff=0.7052 (true 0.7000) | hx_eff=0.2970 (true 0.3000) | hz_eff=0.9736 (true 1.0000)
# [NDE(t)] Step   34/300 | Loss=2.077388 | Jxx_eff=0.1357 (true 0.1000) | Jyy_eff=0.1659 (true 0.2000) | Jzz_eff=0.7010 (true 0.7000) | hx_eff=0.2998 (true 0.3000) | hz_eff=0.9764 (true 1.0000)
# [NDE(t)] Step   35/300 | Loss=2.076199 | Jxx_eff=0.1340 (true 0.1000) | Jyy_eff=0.1678 (true 0.2000) | Jzz_eff=0.6992 (true 0.7000) | hx_eff=0.3012 (true 0.3000) | hz_eff=0.9833 (true 1.0000)
# [NDE(t)] Step   36/300 | Loss=2.073870 | Jxx_eff=0.1305 (true 0.1000) | Jyy_eff=0.1706 (true 0.2000) | Jzz_eff=0.7002 (true 0.7000) | hx_eff=0.3011 (true 0.3000) | hz_eff=0.9927 (true 1.0000)
# [NDE(t)] Step   37/300 | Loss=2.071680 | Jxx_eff=0.1263 (true 0.1000) | Jyy_eff=0.1743 (true 0.2000) | Jzz_eff=0.7034 (true 0.7000) | hx_eff=0.2997 (true 0.3000) | hz_eff=1.0028 (true 1.0000)
# [NDE(t)] Step   38/300 | Loss=2.070731 | Jxx_eff=0.1225 (true 0.1000) | Jyy_eff=0.1791 (true 0.2000) | Jzz_eff=0.7079 (true 0.7000) | hx_eff=0.2975 (true 0.3000) | hz_eff=1.0117 (true 1.0000)
# [NDE(t)] Step   39/300 | Loss=2.071229 | Jxx_eff=0.1199 (true 0.1000) | Jyy_eff=0.1847 (true 0.2000) | Jzz_eff=0.7125 (true 0.7000) | hx_eff=0.2954 (true 0.3000) | hz_eff=1.0178 (true 1.0000)
# [NDE(t)] Step   40/300 | Loss=2.072413 | Jxx_eff=0.1186 (true 0.1000) | Jyy_eff=0.1907 (true 0.2000) | Jzz_eff=0.7162 (true 0.7000) | hx_eff=0.2943 (true 0.3000) | hz_eff=1.0203 (true 1.0000)
# [NDE(t)] Step   41/300 | Loss=2.073247 | Jxx_eff=0.1176 (true 0.1000) | Jyy_eff=0.1960 (true 0.2000) | Jzz_eff=0.7182 (true 0.7000) | hx_eff=0.2945 (true 0.3000) | hz_eff=1.0190 (true 1.0000)
# [NDE(t)] Step   42/300 | Loss=2.073164 | Jxx_eff=0.1160 (true 0.1000) | Jyy_eff=0.1996 (true 0.2000) | Jzz_eff=0.7184 (true 0.7000) | hx_eff=0.2958 (true 0.3000) | hz_eff=1.0145 (true 1.0000)
# [NDE(t)] Step   43/300 | Loss=2.072213 | Jxx_eff=0.1132 (true 0.1000) | Jyy_eff=0.2012 (true 0.2000) | Jzz_eff=0.7168 (true 0.7000) | hx_eff=0.2976 (true 0.3000) | hz_eff=1.0078 (true 1.0000)
# [NDE(t)] Step   44/300 | Loss=2.070969 | Jxx_eff=0.1090 (true 0.1000) | Jyy_eff=0.2007 (true 0.2000) | Jzz_eff=0.7142 (true 0.7000) | hx_eff=0.2993 (true 0.3000) | hz_eff=1.0003 (true 1.0000)
# [NDE(t)] Step   45/300 | Loss=2.070111 | Jxx_eff=0.1042 (true 0.1000) | Jyy_eff=0.1990 (true 0.2000) | Jzz_eff=0.7113 (true 0.7000) | hx_eff=0.3003 (true 0.3000) | hz_eff=0.9931 (true 1.0000)
# [NDE(t)] Step   46/300 | Loss=2.070052 | Jxx_eff=0.0997 (true 0.1000) | Jyy_eff=0.1970 (true 0.2000) | Jzz_eff=0.7087 (true 0.7000) | hx_eff=0.3003 (true 0.3000) | hz_eff=0.9873 (true 1.0000)
# [NDE(t)] Step   47/300 | Loss=2.070679 | Jxx_eff=0.0967 (true 0.1000) | Jyy_eff=0.1958 (true 0.2000) | Jzz_eff=0.7072 (true 0.7000) | hx_eff=0.2994 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step   48/300 | Loss=2.071392 | Jxx_eff=0.0956 (true 0.1000) | Jyy_eff=0.1959 (true 0.2000) | Jzz_eff=0.7069 (true 0.7000) | hx_eff=0.2979 (true 0.3000) | hz_eff=0.9822 (true 1.0000)
# [NDE(t)] Step   49/300 | Loss=2.071621 | Jxx_eff=0.0966 (true 0.1000) | Jyy_eff=0.1973 (true 0.2000) | Jzz_eff=0.7077 (true 0.7000) | hx_eff=0.2966 (true 0.3000) | hz_eff=0.9832 (true 1.0000)
# [NDE(t)] Step   50/300 | Loss=2.071246 | Jxx_eff=0.0988 (true 0.1000) | Jyy_eff=0.1994 (true 0.2000) | Jzz_eff=0.7094 (true 0.7000) | hx_eff=0.2959 (true 0.3000) | hz_eff=0.9862 (true 1.0000)
# [NDE(t)] Step   51/300 | Loss=2.070593 | Jxx_eff=0.1013 (true 0.1000) | Jyy_eff=0.2013 (true 0.2000) | Jzz_eff=0.7114 (true 0.7000) | hx_eff=0.2962 (true 0.3000) | hz_eff=0.9906 (true 1.0000)
# [NDE(t)] Step   52/300 | Loss=2.070083 | Jxx_eff=0.1035 (true 0.1000) | Jyy_eff=0.2025 (true 0.2000) | Jzz_eff=0.7131 (true 0.7000) | hx_eff=0.2973 (true 0.3000) | hz_eff=0.9954 (true 1.0000)
# [NDE(t)] Step   53/300 | Loss=2.069938 | Jxx_eff=0.1047 (true 0.1000) | Jyy_eff=0.2025 (true 0.2000) | Jzz_eff=0.7140 (true 0.7000) | hx_eff=0.2988 (true 0.3000) | hz_eff=0.9998 (true 1.0000)
# [NDE(t)] Step   54/300 | Loss=2.070106 | Jxx_eff=0.1053 (true 0.1000) | Jyy_eff=0.2013 (true 0.2000) | Jzz_eff=0.7138 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=1.0031 (true 1.0000)
# [NDE(t)] Step   55/300 | Loss=2.070370 | Jxx_eff=0.1056 (true 0.1000) | Jyy_eff=0.1995 (true 0.2000) | Jzz_eff=0.7125 (true 0.7000) | hx_eff=0.3005 (true 0.3000) | hz_eff=1.0047 (true 1.0000)
# [NDE(t)] Step   56/300 | Loss=2.070510 | Jxx_eff=0.1061 (true 0.1000) | Jyy_eff=0.1976 (true 0.2000) | Jzz_eff=0.7105 (true 0.7000) | hx_eff=0.3003 (true 0.3000) | hz_eff=1.0044 (true 1.0000)
# [NDE(t)] Step   57/300 | Loss=2.070428 | Jxx_eff=0.1070 (true 0.1000) | Jyy_eff=0.1959 (true 0.2000) | Jzz_eff=0.7082 (true 0.7000) | hx_eff=0.2995 (true 0.3000) | hz_eff=1.0024 (true 1.0000)
# [NDE(t)] Step   58/300 | Loss=2.070189 | Jxx_eff=0.1084 (true 0.1000) | Jyy_eff=0.1945 (true 0.2000) | Jzz_eff=0.7063 (true 0.7000) | hx_eff=0.2986 (true 0.3000) | hz_eff=0.9992 (true 1.0000)
# [NDE(t)] Step   59/300 | Loss=2.069956 | Jxx_eff=0.1097 (true 0.1000) | Jyy_eff=0.1935 (true 0.2000) | Jzz_eff=0.7051 (true 0.7000) | hx_eff=0.2979 (true 0.3000) | hz_eff=0.9955 (true 1.0000)
# [NDE(t)] Step   60/300 | Loss=2.069866 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1926 (true 0.2000) | Jzz_eff=0.7049 (true 0.7000) | hx_eff=0.2977 (true 0.3000) | hz_eff=0.9920 (true 1.0000)
# [NDE(t)] Step   61/300 | Loss=2.069918 | Jxx_eff=0.1103 (true 0.1000) | Jyy_eff=0.1918 (true 0.2000) | Jzz_eff=0.7056 (true 0.7000) | hx_eff=0.2982 (true 0.3000) | hz_eff=0.9895 (true 1.0000)
# [NDE(t)] Step   62/300 | Loss=2.070019 | Jxx_eff=0.1094 (true 0.1000) | Jyy_eff=0.1912 (true 0.2000) | Jzz_eff=0.7069 (true 0.7000) | hx_eff=0.2989 (true 0.3000) | hz_eff=0.9882 (true 1.0000)
# [NDE(t)] Step   63/300 | Loss=2.070091 | Jxx_eff=0.1082 (true 0.1000) | Jyy_eff=0.1912 (true 0.2000) | Jzz_eff=0.7082 (true 0.7000) | hx_eff=0.2995 (true 0.3000) | hz_eff=0.9882 (true 1.0000)
# [NDE(t)] Step   64/300 | Loss=2.070092 | Jxx_eff=0.1070 (true 0.1000) | Jyy_eff=0.1921 (true 0.2000) | Jzz_eff=0.7092 (true 0.7000) | hx_eff=0.2996 (true 0.3000) | hz_eff=0.9894 (true 1.0000)
# [NDE(t)] Step   65/300 | Loss=2.070015 | Jxx_eff=0.1063 (true 0.1000) | Jyy_eff=0.1938 (true 0.2000) | Jzz_eff=0.7096 (true 0.7000) | hx_eff=0.2992 (true 0.3000) | hz_eff=0.9913 (true 1.0000)
# [NDE(t)] Step   66/300 | Loss=2.069891 | Jxx_eff=0.1059 (true 0.1000) | Jyy_eff=0.1962 (true 0.2000) | Jzz_eff=0.7092 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9936 (true 1.0000)
# [NDE(t)] Step   67/300 | Loss=2.069795 | Jxx_eff=0.1058 (true 0.1000) | Jyy_eff=0.1987 (true 0.2000) | Jzz_eff=0.7082 (true 0.7000) | hx_eff=0.2980 (true 0.3000) | hz_eff=0.9957 (true 1.0000)
# [NDE(t)] Step   68/300 | Loss=2.069784 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.2009 (true 0.2000) | Jzz_eff=0.7069 (true 0.7000) | hx_eff=0.2979 (true 0.3000) | hz_eff=0.9974 (true 1.0000)
# [NDE(t)] Step   69/300 | Loss=2.069844 | Jxx_eff=0.1049 (true 0.1000) | Jyy_eff=0.2024 (true 0.2000) | Jzz_eff=0.7058 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9982 (true 1.0000)
# [NDE(t)] Step   70/300 | Loss=2.069907 | Jxx_eff=0.1038 (true 0.1000) | Jyy_eff=0.2031 (true 0.2000) | Jzz_eff=0.7050 (true 0.7000) | hx_eff=0.2996 (true 0.3000) | hz_eff=0.9982 (true 1.0000)
# [NDE(t)] Step   71/300 | Loss=2.069918 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2031 (true 0.2000) | Jzz_eff=0.7048 (true 0.7000) | hx_eff=0.3005 (true 0.3000) | hz_eff=0.9974 (true 1.0000)
# [NDE(t)] Step   72/300 | Loss=2.069876 | Jxx_eff=0.1016 (true 0.1000) | Jyy_eff=0.2027 (true 0.2000) | Jzz_eff=0.7052 (true 0.7000) | hx_eff=0.3010 (true 0.3000) | hz_eff=0.9960 (true 1.0000)
# [NDE(t)] Step   73/300 | Loss=2.069813 | Jxx_eff=0.1011 (true 0.1000) | Jyy_eff=0.2022 (true 0.2000) | Jzz_eff=0.7058 (true 0.7000) | hx_eff=0.3008 (true 0.3000) | hz_eff=0.9942 (true 1.0000)
# [NDE(t)] Step   74/300 | Loss=2.069769 | Jxx_eff=0.1010 (true 0.1000) | Jyy_eff=0.2018 (true 0.2000) | Jzz_eff=0.7066 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9926 (true 1.0000)
# [NDE(t)] Step   75/300 | Loss=2.069770 | Jxx_eff=0.1012 (true 0.1000) | Jyy_eff=0.2016 (true 0.2000) | Jzz_eff=0.7073 (true 0.7000) | hx_eff=0.2991 (true 0.3000) | hz_eff=0.9913 (true 1.0000)
# [NDE(t)] Step   76/300 | Loss=2.069807 | Jxx_eff=0.1016 (true 0.1000) | Jyy_eff=0.2013 (true 0.2000) | Jzz_eff=0.7076 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9907 (true 1.0000)
# [NDE(t)] Step   77/300 | Loss=2.069842 | Jxx_eff=0.1019 (true 0.1000) | Jyy_eff=0.2009 (true 0.2000) | Jzz_eff=0.7075 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step   78/300 | Loss=2.069837 | Jxx_eff=0.1020 (true 0.1000) | Jyy_eff=0.2004 (true 0.2000) | Jzz_eff=0.7070 (true 0.7000) | hx_eff=0.2991 (true 0.3000) | hz_eff=0.9915 (true 1.0000)
# [NDE(t)] Step   79/300 | Loss=2.069798 | Jxx_eff=0.1022 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7063 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9926 (true 1.0000)
# [NDE(t)] Step   80/300 | Loss=2.069760 | Jxx_eff=0.1025 (true 0.1000) | Jyy_eff=0.1998 (true 0.2000) | Jzz_eff=0.7056 (true 0.7000) | hx_eff=0.3008 (true 0.3000) | hz_eff=0.9939 (true 1.0000)
# [NDE(t)] Step   81/300 | Loss=2.069751 | Jxx_eff=0.1029 (true 0.1000) | Jyy_eff=0.1998 (true 0.2000) | Jzz_eff=0.7051 (true 0.7000) | hx_eff=0.3011 (true 0.3000) | hz_eff=0.9950 (true 1.0000)
# [NDE(t)] Step   82/300 | Loss=2.069765 | Jxx_eff=0.1032 (true 0.1000) | Jyy_eff=0.1998 (true 0.2000) | Jzz_eff=0.7050 (true 0.7000) | hx_eff=0.3010 (true 0.3000) | hz_eff=0.9954 (true 1.0000)
# [NDE(t)] Step   83/300 | Loss=2.069773 | Jxx_eff=0.1035 (true 0.1000) | Jyy_eff=0.1999 (true 0.2000) | Jzz_eff=0.7050 (true 0.7000) | hx_eff=0.3008 (true 0.3000) | hz_eff=0.9956 (true 1.0000)
# [NDE(t)] Step   84/300 | Loss=2.069776 | Jxx_eff=0.1037 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.7052 (true 0.7000) | hx_eff=0.3004 (true 0.3000) | hz_eff=0.9956 (true 1.0000)
# [NDE(t)] Step   85/300 | Loss=2.069774 | Jxx_eff=0.1039 (true 0.1000) | Jyy_eff=0.1999 (true 0.2000) | Jzz_eff=0.7055 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9954 (true 1.0000)
# [NDE(t)] Step   86/300 | Loss=2.069768 | Jxx_eff=0.1038 (true 0.1000) | Jyy_eff=0.1998 (true 0.2000) | Jzz_eff=0.7058 (true 0.7000) | hx_eff=0.2997 (true 0.3000) | hz_eff=0.9951 (true 1.0000)
# [NDE(t)] Step   87/300 | Loss=2.069761 | Jxx_eff=0.1037 (true 0.1000) | Jyy_eff=0.1996 (true 0.2000) | Jzz_eff=0.7061 (true 0.7000) | hx_eff=0.2996 (true 0.3000) | hz_eff=0.9947 (true 1.0000)
# [NDE(t)] Step   88/300 | Loss=2.069755 | Jxx_eff=0.1034 (true 0.1000) | Jyy_eff=0.1994 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.2997 (true 0.3000) | hz_eff=0.9942 (true 1.0000)
# [NDE(t)] Step   89/300 | Loss=2.069751 | Jxx_eff=0.1031 (true 0.1000) | Jyy_eff=0.1992 (true 0.2000) | Jzz_eff=0.7066 (true 0.7000) | hx_eff=0.2999 (true 0.3000) | hz_eff=0.9938 (true 1.0000)
# [NDE(t)] Step   90/300 | Loss=2.069751 | Jxx_eff=0.1029 (true 0.1000) | Jyy_eff=0.1991 (true 0.2000) | Jzz_eff=0.7066 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9934 (true 1.0000)
# [NDE(t)] Step   91/300 | Loss=2.069753 | Jxx_eff=0.1027 (true 0.1000) | Jyy_eff=0.1991 (true 0.2000) | Jzz_eff=0.7066 (true 0.7000) | hx_eff=0.3003 (true 0.3000) | hz_eff=0.9931 (true 1.0000)
# [NDE(t)] Step   92/300 | Loss=2.069755 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.1991 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3005 (true 0.3000) | hz_eff=0.9929 (true 1.0000)
# [NDE(t)] Step   93/300 | Loss=2.069757 | Jxx_eff=0.1025 (true 0.1000) | Jyy_eff=0.1994 (true 0.2000) | Jzz_eff=0.7062 (true 0.7000) | hx_eff=0.3005 (true 0.3000) | hz_eff=0.9928 (true 1.0000)
# [NDE(t)] Step   94/300 | Loss=2.069756 | Jxx_eff=0.1025 (true 0.1000) | Jyy_eff=0.1996 (true 0.2000) | Jzz_eff=0.7060 (true 0.7000) | hx_eff=0.3004 (true 0.3000) | hz_eff=0.9928 (true 1.0000)
# [NDE(t)] Step   95/300 | Loss=2.069754 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.1999 (true 0.2000) | Jzz_eff=0.7059 (true 0.7000) | hx_eff=0.3003 (true 0.3000) | hz_eff=0.9930 (true 1.0000)
# [NDE(t)] Step   96/300 | Loss=2.069752 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2002 (true 0.2000) | Jzz_eff=0.7057 (true 0.7000) | hx_eff=0.3002 (true 0.3000) | hz_eff=0.9932 (true 1.0000)
# [NDE(t)] Step   97/300 | Loss=2.069750 | Jxx_eff=0.1025 (true 0.1000) | Jyy_eff=0.2005 (true 0.2000) | Jzz_eff=0.7057 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9935 (true 1.0000)
# [NDE(t)] Step   98/300 | Loss=2.069748 | Jxx_eff=0.1024 (true 0.1000) | Jyy_eff=0.2006 (true 0.2000) | Jzz_eff=0.7058 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9938 (true 1.0000)
# [NDE(t)] Step   99/300 | Loss=2.069748 | Jxx_eff=0.1023 (true 0.1000) | Jyy_eff=0.2007 (true 0.2000) | Jzz_eff=0.7059 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9941 (true 1.0000)
# [NDE(t)] Step  100/300 | Loss=2.069748 | Jxx_eff=0.1022 (true 0.1000) | Jyy_eff=0.2008 (true 0.2000) | Jzz_eff=0.7061 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9943 (true 1.0000)
# [NDE(t)] Step  101/300 | Loss=2.069748 | Jxx_eff=0.1021 (true 0.1000) | Jyy_eff=0.2008 (true 0.2000) | Jzz_eff=0.7063 (true 0.7000) | hx_eff=0.3002 (true 0.3000) | hz_eff=0.9945 (true 1.0000)
# [NDE(t)] Step  102/300 | Loss=2.069749 | Jxx_eff=0.1021 (true 0.1000) | Jyy_eff=0.2008 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3002 (true 0.3000) | hz_eff=0.9945 (true 1.0000)
# [NDE(t)] Step  103/300 | Loss=2.069750 | Jxx_eff=0.1022 (true 0.1000) | Jyy_eff=0.2008 (true 0.2000) | Jzz_eff=0.7065 (true 0.7000) | hx_eff=0.3002 (true 0.3000) | hz_eff=0.9945 (true 1.0000)
# [NDE(t)] Step  104/300 | Loss=2.069750 | Jxx_eff=0.1022 (true 0.1000) | Jyy_eff=0.2008 (true 0.2000) | Jzz_eff=0.7065 (true 0.7000) | hx_eff=0.3002 (true 0.3000) | hz_eff=0.9944 (true 1.0000)
# [NDE(t)] Step  105/300 | Loss=2.069749 | Jxx_eff=0.1023 (true 0.1000) | Jyy_eff=0.2008 (true 0.2000) | Jzz_eff=0.7065 (true 0.7000) | hx_eff=0.3002 (true 0.3000) | hz_eff=0.9943 (true 1.0000)
# [NDE(t)] Step  106/300 | Loss=2.069748 | Jxx_eff=0.1024 (true 0.1000) | Jyy_eff=0.2007 (true 0.2000) | Jzz_eff=0.7065 (true 0.7000) | hx_eff=0.3002 (true 0.3000) | hz_eff=0.9942 (true 1.0000)
# [NDE(t)] Step  107/300 | Loss=2.069747 | Jxx_eff=0.1025 (true 0.1000) | Jyy_eff=0.2007 (true 0.2000) | Jzz_eff=0.7065 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9941 (true 1.0000)
# [NDE(t)] Step  108/300 | Loss=2.069747 | Jxx_eff=0.1025 (true 0.1000) | Jyy_eff=0.2006 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9939 (true 1.0000)
# [NDE(t)] Step  109/300 | Loss=2.069746 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2006 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9938 (true 1.0000)
# [NDE(t)] Step  110/300 | Loss=2.069746 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2005 (true 0.2000) | Jzz_eff=0.7063 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9937 (true 1.0000)
# [NDE(t)] Step  111/300 | Loss=2.069746 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2004 (true 0.2000) | Jzz_eff=0.7063 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9936 (true 1.0000)
# [NDE(t)] Step  112/300 | Loss=2.069746 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2003 (true 0.2000) | Jzz_eff=0.7062 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9935 (true 1.0000)
# [NDE(t)] Step  113/300 | Loss=2.069746 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2002 (true 0.2000) | Jzz_eff=0.7062 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9935 (true 1.0000)
# [NDE(t)] Step  114/300 | Loss=2.069746 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7062 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9935 (true 1.0000)
# [NDE(t)] Step  115/300 | Loss=2.069746 | Jxx_eff=0.1026 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.7062 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9935 (true 1.0000)
# [NDE(t)] Step  116/300 | Loss=2.069746 | Jxx_eff=0.1027 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.7062 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9935 (true 1.0000)
# [NDE(t)] Step  117/300 | Loss=2.069746 | Jxx_eff=0.1027 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.7062 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9935 (true 1.0000)
# [NDE(t)] Step  118/300 | Loss=2.069746 | Jxx_eff=0.1028 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.7063 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9936 (true 1.0000)
# [NDE(t)] Step  119/300 | Loss=2.069746 | Jxx_eff=0.1028 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.7063 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9937 (true 1.0000)
# [NDE(t)] Step  120/300 | Loss=2.069746 | Jxx_eff=0.1029 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.7063 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9937 (true 1.0000)
# [NDE(t)] Step  121/300 | Loss=2.069745 | Jxx_eff=0.1029 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9938 (true 1.0000)
# [NDE(t)] Step  122/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9939 (true 1.0000)
# [NDE(t)] Step  123/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9939 (true 1.0000)
# [NDE(t)] Step  124/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9940 (true 1.0000)
# [NDE(t)] Step  125/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9940 (true 1.0000)
# [NDE(t)] Step  126/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9940 (true 1.0000)
# [NDE(t)] Step  127/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9940 (true 1.0000)
# [NDE(t)] Step  128/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9940 (true 1.0000)
# [NDE(t)] Step  129/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9940 (true 1.0000)
# [NDE(t)] Step  130/300 | Loss=2.069745 | Jxx_eff=0.1030 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9940 (true 1.0000)
# [NDE(t)] Step  131/300 | Loss=2.069745 | Jxx_eff=0.1029 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.7064 (true 0.7000) | hx_eff=0.3000 (true 0.3000) | hz_eff=0.9940 (true 1.0000)
# [EarlyStopping] Parando en step 131 porque la loss no mejora (min_delta=1e-05) en 50 iteraciones. Best=2.069751

# %%
print(relative_param_error(history_nde_modificado["c_eff"][-1], history_nde_modificado["true"]))
# Out:
# 0.006701813274897073

# %% [markdown]
# ## robustness

# %%
def robustness_study_nde(
    dataset: dict,
    n_runs: int = 20,
    init_low: float = 0.0,
    init_high: float = 1.0,
    success_threshold: float = 0.1,
    num_steps: int = 500,
    lr: float = 1e-2,
    hidden: int = 32,
    dc_scale: float = 0.01,
    m: int = 20,
    regularization: float = 0.001,
    patience_stop: int = 50,
    min_delta: float = 1e-5,
    device: str = "cpu",
    seed: int = 0,
    verbose_each_run: bool = False,
):
    rng = np.random.default_rng(seed)

    errors = []
    final_loss = []
    final_params = []
    steps_used = []

    for r in range(n_runs):
        init_params = rng.uniform(init_low, init_high, size=5)

        hist = train_neural_ode_model(
            dataset,
            num_steps=num_steps,
            lr=lr,
            hidden=hidden,
            dc_scale=dc_scale,
            m=m,
            regularization=regularization,
            init=init_params,
            patience_stop=patience_stop,
            min_delta=min_delta,
            device=device,
            everbose=verbose_each_run,
        )

        theta_true = hist["true"]
        theta_hat = hist["c_eff"][-1]  # <-- IMPORTANTE: usar c_eff
        loss_last = hist["loss"][-1]
        steps_last = len(hist["loss"])

        err = relative_param_error(theta_hat, theta_true)

        errors.append(err)
        final_loss.append(loss_last)
        final_params.append(theta_hat.copy())
        steps_used.append(steps_last)


        print(f"[NDE] Run {r+1:02d}/{n_runs} | steps={steps_last:4d} | loss={loss_last:.5f} | rel.err={err:.4f}")

    errors = np.array(errors)
    final_loss = np.array(final_loss)
    final_params = np.array(final_params)
    steps_used = np.array(steps_used)

    success = errors < success_threshold
    success_rate = float(np.mean(success))

    results = {
        "errors": errors,
        "final_loss": final_loss,
        "final_params": final_params,
        "steps_used": steps_used,
        "success": success,
        "success_threshold": success_threshold,
        "success_rate": success_rate,
    }
    return results


def plot_robustness_hist(results: dict, bins: int = 12, title_prefix: str = "Model"):
    errors = results["errors"]
    thr = results["success_threshold"]
    success_rate = results["success_rate"]

    # Histograma error relativo
    plt.figure()
    plt.hist(errors, bins=bins)
    plt.axvline(thr, linestyle="--", linewidth=2, label=f"success threshold = {thr}")
    plt.xlabel(r"Relative parameter error")
    plt.ylabel("Count")
    plt.title(f"{title_prefix} robustness\nsuccess rate = {success_rate*100:.1f}%")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()

    # Histograma loss final (compatible con ambos modelos)
    key = "final_nll" if "final_nll" in results else "final_loss"

    plt.figure()
    plt.hist(results[key], bins=bins)
    plt.xlabel("Final loss")
    plt.ylabel("Count")
    plt.title(f"{title_prefix} final loss distribution")
    plt.grid(alpha=0.3)
    plt.show()

rob_nde = robustness_study_nde(
    dataset,
    n_runs=20,
    init_low=0.1,
    init_high=1,
    lr=0.01,
    hidden=32,
    dc_scale=0.2,
    m=30,
    regularization=0.001,
    patience_stop=50,
    min_delta=1e-5,
    success_threshold=0.1,
    seed=123,
    verbose_each_run=True,
)

plot_robustness_hist(rob_nde, bins=10, title_prefix="Neural ODE")

print("NDE Success rate:", rob_nde["success_rate"])
print("Errors (mean ± std):", rob_nde["errors"].mean(), "±", rob_nde["errors"].std())
# Out:
# [NDE(t)] Step    1/500 | Loss=3.282843 | Jxx_eff=0.7153 (true 0.1000) | Jyy_eff=0.1162 (true 0.2000) | Jzz_eff=0.3453 (true 0.7000) | hx_eff=0.2783 (true 0.3000) | hz_eff=0.3024 (true 1.0000)
# [NDE(t)] Step    2/500 | Loss=3.052463 | Jxx_eff=0.6918 (true 0.1000) | Jyy_eff=0.0848 (true 0.2000) | Jzz_eff=0.3910 (true 0.7000) | hx_eff=0.2643 (true 0.3000) | hz_eff=0.3488 (true 1.0000)
# [NDE(t)] Step    3/500 | Loss=2.946588 | Jxx_eff=0.6627 (true 0.1000) | Jyy_eff=0.0649 (true 0.2000) | Jzz_eff=0.4345 (true 0.7000) | hx_eff=0.2400 (true 0.3000) | hz_eff=0.3964 (true 1.0000)
# [NDE(t)] Step    4/500 | Loss=2.821721 | Jxx_eff=0.6320 (true 0.1000) | Jyy_eff=0.0512 (true 0.2000) | Jzz_eff=0.4830 (true 0.7000) | hx_eff=0.2077 (true 0.3000) | hz_eff=0.4487 (true 1.0000)
# [NDE(t)] Step    5/500 | Loss=2.699556 | Jxx_eff=0.5951 (true 0.1000) | Jyy_eff=0.0457 (true 0.2000) | Jzz_eff=0.5317 (true 0.7000) | hx_eff=0.1671 (true 0.3000) | hz_eff=0.5033 (true 1.0000)
# [NDE(t)] Step    6/500 | Loss=2.633671 | Jxx_eff=0.5506 (true 0.1000) | Jyy_eff=0.0536 (true 0.2000) | Jzz_eff=0.5751 (true 0.7000) | hx_eff=0.1188 (true 0.3000) | hz_eff=0.5588 (true 1.0000)
# [NDE(t)] Step    7/500 | Loss=2.570563 | Jxx_eff=0.4989 (true 0.1000) | Jyy_eff=0.0605 (true 0.2000) | Jzz_eff=0.6241 (true 0.7000) | hx_eff=0.0746 (true 0.3000) | hz_eff=0.6225 (true 1.0000)
# [NDE(t)] Step    8/500 | Loss=2.487313 | Jxx_eff=0.4398 (true 0.1000) | Jyy_eff=0.0594 (true 0.2000) | Jzz_eff=0.6805 (true 0.7000) | hx_eff=0.0493 (true 0.3000) | hz_eff=0.6943 (true 1.0000)
# [NDE(t)] Step    9/500 | Loss=2.401364 | Jxx_eff=0.3758 (true 0.1000) | Jyy_eff=0.0533 (true 0.2000) | Jzz_eff=0.7332 (true 0.7000) | hx_eff=0.0447 (true 0.3000) | hz_eff=0.7724 (true 1.0000)
# [NDE(t)] Step   10/500 | Loss=2.359700 | Jxx_eff=0.3125 (true 0.1000) | Jyy_eff=0.0502 (true 0.2000) | Jzz_eff=0.7576 (true 0.7000) | hx_eff=0.0562 (true 0.3000) | hz_eff=0.8494 (true 1.0000)
# [NDE(t)] Step   11/500 | Loss=2.343034 | Jxx_eff=0.2589 (true 0.1000) | Jyy_eff=0.0626 (true 0.2000) | Jzz_eff=0.7468 (true 0.7000) | hx_eff=0.0807 (true 0.3000) | hz_eff=0.9014 (true 1.0000)
# [NDE(t)] Step   12/500 | Loss=2.304652 | Jxx_eff=0.2198 (true 0.1000) | Jyy_eff=0.0869 (true 0.2000) | Jzz_eff=0.7186 (true 0.7000) | hx_eff=0.1141 (true 0.3000) | hz_eff=0.9344 (true 1.0000)
# [NDE(t)] Step   13/500 | Loss=2.248413 | Jxx_eff=0.1966 (true 0.1000) | Jyy_eff=0.1192 (true 0.2000) | Jzz_eff=0.6782 (true 0.7000) | hx_eff=0.1532 (true 0.3000) | hz_eff=0.9403 (true 1.0000)
# [NDE(t)] Step   14/500 | Loss=2.169761 | Jxx_eff=0.1862 (true 0.1000) | Jyy_eff=0.1550 (true 0.2000) | Jzz_eff=0.6329 (true 0.7000) | hx_eff=0.1929 (true 0.3000) | hz_eff=0.9276 (true 1.0000)
# [NDE(t)] Step   15/500 | Loss=2.103974 | Jxx_eff=0.1831 (true 0.1000) | Jyy_eff=0.1913 (true 0.2000) | Jzz_eff=0.5902 (true 0.7000) | hx_eff=0.2313 (true 0.3000) | hz_eff=0.9053 (true 1.0000)
# [NDE(t)] Step   16/500 | Loss=2.090747 | Jxx_eff=0.1804 (true 0.1000) | Jyy_eff=0.2225 (true 0.2000) | Jzz_eff=0.5595 (true 0.7000) | hx_eff=0.2663 (true 0.3000) | hz_eff=0.8849 (true 1.0000)
# [NDE(t)] Step   17/500 | Loss=2.125515 | Jxx_eff=0.1733 (true 0.1000) | Jyy_eff=0.2457 (true 0.2000) | Jzz_eff=0.5447 (true 0.7000) | hx_eff=0.2967 (true 0.3000) | hz_eff=0.8744 (true 1.0000)
# [NDE(t)] Step   18/500 | Loss=2.162493 | Jxx_eff=0.1602 (true 0.1000) | Jyy_eff=0.2599 (true 0.2000) | Jzz_eff=0.5446 (true 0.7000) | hx_eff=0.3207 (true 0.3000) | hz_eff=0.8763 (true 1.0000)
# [NDE(t)] Step   19/500 | Loss=2.175623 | Jxx_eff=0.1420 (true 0.1000) | Jyy_eff=0.2664 (true 0.2000) | Jzz_eff=0.5556 (true 0.7000) | hx_eff=0.3369 (true 0.3000) | hz_eff=0.8879 (true 1.0000)
# [NDE(t)] Step   20/500 | Loss=2.167139 | Jxx_eff=0.1210 (true 0.1000) | Jyy_eff=0.2670 (true 0.2000) | Jzz_eff=0.5739 (true 0.7000) | hx_eff=0.3435 (true 0.3000) | hz_eff=0.9052 (true 1.0000)
# [NDE(t)] Step   21/500 | Loss=2.147959 | Jxx_eff=0.0986 (true 0.1000) | Jyy_eff=0.2630 (true 0.2000) | Jzz_eff=0.5956 (true 0.7000) | hx_eff=0.3412 (true 0.3000) | hz_eff=0.9239 (true 1.0000)
# [NDE(t)] Step   22/500 | Loss=2.131235 | Jxx_eff=0.0795 (true 0.1000) | Jyy_eff=0.2583 (true 0.2000) | Jzz_eff=0.6176 (true 0.7000) | hx_eff=0.3310 (true 0.3000) | hz_eff=0.9413 (true 1.0000)
# [NDE(t)] Step   23/500 | Loss=2.123188 | Jxx_eff=0.0685 (true 0.1000) | Jyy_eff=0.2560 (true 0.2000) | Jzz_eff=0.6359 (true 0.7000) | hx_eff=0.3132 (true 0.3000) | hz_eff=0.9524 (true 1.0000)
# [NDE(t)] Step   24/500 | Loss=2.117969 | Jxx_eff=0.0661 (true 0.1000) | Jyy_eff=0.2575 (true 0.2000) | Jzz_eff=0.6482 (true 0.7000) | hx_eff=0.2895 (true 0.3000) | hz_eff=0.9561 (true 1.0000)
# [NDE(t)] Step   25/500 | Loss=2.107953 | Jxx_eff=0.0723 (true 0.1000) | Jyy_eff=0.2631 (true 0.2000) | Jzz_eff=0.6543 (true 0.7000) | hx_eff=0.2624 (true 0.3000) | hz_eff=0.9531 (true 1.0000)
# [NDE(t)] Step   26/500 | Loss=2.093917 | Jxx_eff=0.0843 (true 0.1000) | Jyy_eff=0.2699 (true 0.2000) | Jzz_eff=0.6553 (true 0.7000) | hx_eff=0.2352 (true 0.3000) | hz_eff=0.9458 (true 1.0000)
# [NDE(t)] Step   27/500 | Loss=2.087051 | Jxx_eff=0.0977 (true 0.1000) | Jyy_eff=0.2734 (true 0.2000) | Jzz_eff=0.6530 (true 0.7000) | hx_eff=0.2121 (true 0.3000) | hz_eff=0.9376 (true 1.0000)
# [NDE(t)] Step   28/500 | Loss=2.091645 | Jxx_eff=0.1094 (true 0.1000) | Jyy_eff=0.2706 (true 0.2000) | Jzz_eff=0.6499 (true 0.7000) | hx_eff=0.1961 (true 0.3000) | hz_eff=0.9318 (true 1.0000)
# [NDE(t)] Step   29/500 | Loss=2.100648 | Jxx_eff=0.1174 (true 0.1000) | Jyy_eff=0.2605 (true 0.2000) | Jzz_eff=0.6476 (true 0.7000) | hx_eff=0.1884 (true 0.3000) | hz_eff=0.9304 (true 1.0000)
# [NDE(t)] Step   30/500 | Loss=2.104975 | Jxx_eff=0.1214 (true 0.1000) | Jyy_eff=0.2441 (true 0.2000) | Jzz_eff=0.6469 (true 0.7000) | hx_eff=0.1891 (true 0.3000) | hz_eff=0.9339 (true 1.0000)
# [NDE(t)] Step   31/500 | Loss=2.101423 | Jxx_eff=0.1226 (true 0.1000) | Jyy_eff=0.2236 (true 0.2000) | Jzz_eff=0.6478 (true 0.7000) | hx_eff=0.1971 (true 0.3000) | hz_eff=0.9416 (true 1.0000)
# [NDE(t)] Step   32/500 | Loss=2.092840 | Jxx_eff=0.1229 (true 0.1000) | Jyy_eff=0.2018 (true 0.2000) | Jzz_eff=0.6497 (true 0.7000) | hx_eff=0.2109 (true 0.3000) | hz_eff=0.9516 (true 1.0000)
# [NDE(t)] Step   33/500 | Loss=2.084931 | Jxx_eff=0.1246 (true 0.1000) | Jyy_eff=0.1823 (true 0.2000) | Jzz_eff=0.6516 (true 0.7000) | hx_eff=0.2286 (true 0.3000) | hz_eff=0.9614 (true 1.0000)
# [NDE(t)] Step   34/500 | Loss=2.081167 | Jxx_eff=0.1297 (true 0.1000) | Jyy_eff=0.1682 (true 0.2000) | Jzz_eff=0.6526 (true 0.7000) | hx_eff=0.2479 (true 0.3000) | hz_eff=0.9683 (true 1.0000)
# [NDE(t)] Step   35/500 | Loss=2.080183 | Jxx_eff=0.1388 (true 0.1000) | Jyy_eff=0.1613 (true 0.2000) | Jzz_eff=0.6524 (true 0.7000) | hx_eff=0.2669 (true 0.3000) | hz_eff=0.9710 (true 1.0000)
# [NDE(t)] Step   36/500 | Loss=2.078965 | Jxx_eff=0.1504 (true 0.1000) | Jyy_eff=0.1606 (true 0.2000) | Jzz_eff=0.6507 (true 0.7000) | hx_eff=0.2837 (true 0.3000) | hz_eff=0.9692 (true 1.0000)
# [NDE(t)] Step   37/500 | Loss=2.077320 | Jxx_eff=0.1619 (true 0.1000) | Jyy_eff=0.1640 (true 0.2000) | Jzz_eff=0.6482 (true 0.7000) | hx_eff=0.2972 (true 0.3000) | hz_eff=0.9641 (true 1.0000)
# [NDE(t)] Step   38/500 | Loss=2.077352 | Jxx_eff=0.1705 (true 0.1000) | Jyy_eff=0.1687 (true 0.2000) | Jzz_eff=0.6456 (true 0.7000) | hx_eff=0.3069 (true 0.3000) | hz_eff=0.9580 (true 1.0000)
# [NDE(t)] Step   39/500 | Loss=2.079988 | Jxx_eff=0.1736 (true 0.1000) | Jyy_eff=0.1722 (true 0.2000) | Jzz_eff=0.6438 (true 0.7000) | hx_eff=0.3129 (true 0.3000) | hz_eff=0.9533 (true 1.0000)
# [NDE(t)] Step   40/500 | Loss=2.082966 | Jxx_eff=0.1703 (true 0.1000) | Jyy_eff=0.1734 (true 0.2000) | Jzz_eff=0.6436 (true 0.7000) | hx_eff=0.3154 (true 0.3000) | hz_eff=0.9516 (true 1.0000)
# [NDE(t)] Step   41/500 | Loss=2.083430 | Jxx_eff=0.1614 (true 0.1000) | Jyy_eff=0.1725 (true 0.2000) | Jzz_eff=0.6452 (true 0.7000) | hx_eff=0.3147 (true 0.3000) | hz_eff=0.9535 (true 1.0000)
# [NDE(t)] Step   42/500 | Loss=2.080821 | Jxx_eff=0.1488 (true 0.1000) | Jyy_eff=0.1707 (true 0.2000) | Jzz_eff=0.6486 (true 0.7000) | hx_eff=0.3114 (true 0.3000) | hz_eff=0.9583 (true 1.0000)
# [NDE(t)] Step   43/500 | Loss=2.077175 | Jxx_eff=0.1349 (true 0.1000) | Jyy_eff=0.1697 (true 0.2000) | Jzz_eff=0.6534 (true 0.7000) | hx_eff=0.3058 (true 0.3000) | hz_eff=0.9644 (true 1.0000)
# [NDE(t)] Step   44/500 | Loss=2.074683 | Jxx_eff=0.1226 (true 0.1000) | Jyy_eff=0.1713 (true 0.2000) | Jzz_eff=0.6589 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9697 (true 1.0000)
# [NDE(t)] Step   45/500 | Loss=2.073678 | Jxx_eff=0.1136 (true 0.1000) | Jyy_eff=0.1764 (true 0.2000) | Jzz_eff=0.6643 (true 0.7000) | hx_eff=0.2903 (true 0.3000) | hz_eff=0.9726 (true 1.0000)
# [NDE(t)] Step   46/500 | Loss=2.072958 | Jxx_eff=0.1086 (true 0.1000) | Jyy_eff=0.1844 (true 0.2000) | Jzz_eff=0.6692 (true 0.7000) | hx_eff=0.2821 (true 0.3000) | hz_eff=0.9723 (true 1.0000)
# [NDE(t)] Step   47/500 | Loss=2.072038 | Jxx_eff=0.1064 (true 0.1000) | Jyy_eff=0.1937 (true 0.2000) | Jzz_eff=0.6733 (true 0.7000) | hx_eff=0.2750 (true 0.3000) | hz_eff=0.9694 (true 1.0000)
# [NDE(t)] Step   48/500 | Loss=2.071708 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.2024 (true 0.2000) | Jzz_eff=0.6763 (true 0.7000) | hx_eff=0.2698 (true 0.3000) | hz_eff=0.9652 (true 1.0000)
# [NDE(t)] Step   49/500 | Loss=2.072663 | Jxx_eff=0.1039 (true 0.1000) | Jyy_eff=0.2086 (true 0.2000) | Jzz_eff=0.6784 (true 0.7000) | hx_eff=0.2673 (true 0.3000) | hz_eff=0.9616 (true 1.0000)
# [NDE(t)] Step   50/500 | Loss=2.074141 | Jxx_eff=0.1009 (true 0.1000) | Jyy_eff=0.2114 (true 0.2000) | Jzz_eff=0.6797 (true 0.7000) | hx_eff=0.2675 (true 0.3000) | hz_eff=0.9601 (true 1.0000)
# [NDE(t)] Step   51/500 | Loss=2.074711 | Jxx_eff=0.0963 (true 0.1000) | Jyy_eff=0.2110 (true 0.2000) | Jzz_eff=0.6803 (true 0.7000) | hx_eff=0.2705 (true 0.3000) | hz_eff=0.9611 (true 1.0000)
# [NDE(t)] Step   52/500 | Loss=2.073917 | Jxx_eff=0.0912 (true 0.1000) | Jyy_eff=0.2083 (true 0.2000) | Jzz_eff=0.6803 (true 0.7000) | hx_eff=0.2756 (true 0.3000) | hz_eff=0.9643 (true 1.0000)
# [NDE(t)] Step   53/500 | Loss=2.072650 | Jxx_eff=0.0873 (true 0.1000) | Jyy_eff=0.2047 (true 0.2000) | Jzz_eff=0.6798 (true 0.7000) | hx_eff=0.2822 (true 0.3000) | hz_eff=0.9682 (true 1.0000)
# [NDE(t)] Step   54/500 | Loss=2.071965 | Jxx_eff=0.0862 (true 0.1000) | Jyy_eff=0.2018 (true 0.2000) | Jzz_eff=0.6790 (true 0.7000) | hx_eff=0.2894 (true 0.3000) | hz_eff=0.9715 (true 1.0000)
# [NDE(t)] Step   55/500 | Loss=2.071848 | Jxx_eff=0.0886 (true 0.1000) | Jyy_eff=0.2002 (true 0.2000) | Jzz_eff=0.6779 (true 0.7000) | hx_eff=0.2963 (true 0.3000) | hz_eff=0.9733 (true 1.0000)
# [NDE(t)] Step   56/500 | Loss=2.071683 | Jxx_eff=0.0940 (true 0.1000) | Jyy_eff=0.2000 (true 0.2000) | Jzz_eff=0.6769 (true 0.7000) | hx_eff=0.3023 (true 0.3000) | hz_eff=0.9731 (true 1.0000)
# [NDE(t)] Step   57/500 | Loss=2.071351 | Jxx_eff=0.1010 (true 0.1000) | Jyy_eff=0.2001 (true 0.2000) | Jzz_eff=0.6762 (true 0.7000) | hx_eff=0.3068 (true 0.3000) | hz_eff=0.9715 (true 1.0000)
# [NDE(t)] Step   58/500 | Loss=2.071268 | Jxx_eff=0.1077 (true 0.1000) | Jyy_eff=0.1996 (true 0.2000) | Jzz_eff=0.6760 (true 0.7000) | hx_eff=0.3095 (true 0.3000) | hz_eff=0.9697 (true 1.0000)
# [NDE(t)] Step   59/500 | Loss=2.071613 | Jxx_eff=0.1127 (true 0.1000) | Jyy_eff=0.1974 (true 0.2000) | Jzz_eff=0.6764 (true 0.7000) | hx_eff=0.3106 (true 0.3000) | hz_eff=0.9687 (true 1.0000)
# [NDE(t)] Step   60/500 | Loss=2.071925 | Jxx_eff=0.1150 (true 0.1000) | Jyy_eff=0.1935 (true 0.2000) | Jzz_eff=0.6774 (true 0.7000) | hx_eff=0.3101 (true 0.3000) | hz_eff=0.9693 (true 1.0000)
# [NDE(t)] Step   61/500 | Loss=2.071732 | Jxx_eff=0.1151 (true 0.1000) | Jyy_eff=0.1885 (true 0.2000) | Jzz_eff=0.6788 (true 0.7000) | hx_eff=0.3082 (true 0.3000) | hz_eff=0.9713 (true 1.0000)
# [NDE(t)] Step   62/500 | Loss=2.071196 | Jxx_eff=0.1139 (true 0.1000) | Jyy_eff=0.1835 (true 0.2000) | Jzz_eff=0.6804 (true 0.7000) | hx_eff=0.3052 (true 0.3000) | hz_eff=0.9742 (true 1.0000)
# [NDE(t)] Step   63/500 | Loss=2.070839 | Jxx_eff=0.1127 (true 0.1000) | Jyy_eff=0.1797 (true 0.2000) | Jzz_eff=0.6819 (true 0.7000) | hx_eff=0.3014 (true 0.3000) | hz_eff=0.9769 (true 1.0000)
# [NDE(t)] Step   64/500 | Loss=2.070844 | Jxx_eff=0.1124 (true 0.1000) | Jyy_eff=0.1779 (true 0.2000) | Jzz_eff=0.6831 (true 0.7000) | hx_eff=0.2974 (true 0.3000) | hz_eff=0.9787 (true 1.0000)
# [NDE(t)] Step   65/500 | Loss=2.070951 | Jxx_eff=0.1136 (true 0.1000) | Jyy_eff=0.1784 (true 0.2000) | Jzz_eff=0.6837 (true 0.7000) | hx_eff=0.2931 (true 0.3000) | hz_eff=0.9789 (true 1.0000)
# [NDE(t)] Step   66/500 | Loss=2.070857 | Jxx_eff=0.1155 (true 0.1000) | Jyy_eff=0.1805 (true 0.2000) | Jzz_eff=0.6841 (true 0.7000) | hx_eff=0.2895 (true 0.3000) | hz_eff=0.9780 (true 1.0000)
# [NDE(t)] Step   67/500 | Loss=2.070848 | Jxx_eff=0.1171 (true 0.1000) | Jyy_eff=0.1832 (true 0.2000) | Jzz_eff=0.6844 (true 0.7000) | hx_eff=0.2872 (true 0.3000) | hz_eff=0.9770 (true 1.0000)
# [NDE(t)] Step   68/500 | Loss=2.071025 | Jxx_eff=0.1175 (true 0.1000) | Jyy_eff=0.1857 (true 0.2000) | Jzz_eff=0.6847 (true 0.7000) | hx_eff=0.2865 (true 0.3000) | hz_eff=0.9765 (true 1.0000)
# [NDE(t)] Step   69/500 | Loss=2.071175 | Jxx_eff=0.1163 (true 0.1000) | Jyy_eff=0.1873 (true 0.2000) | Jzz_eff=0.6852 (true 0.7000) | hx_eff=0.2872 (true 0.3000) | hz_eff=0.9770 (true 1.0000)
# [NDE(t)] Step   70/500 | Loss=2.071056 | Jxx_eff=0.1137 (true 0.1000) | Jyy_eff=0.1882 (true 0.2000) | Jzz_eff=0.6858 (true 0.7000) | hx_eff=0.2893 (true 0.3000) | hz_eff=0.9785 (true 1.0000)
# [NDE(t)] Step   71/500 | Loss=2.070753 | Jxx_eff=0.1106 (true 0.1000) | Jyy_eff=0.1888 (true 0.2000) | Jzz_eff=0.6862 (true 0.7000) | hx_eff=0.2923 (true 0.3000) | hz_eff=0.9804 (true 1.0000)
# [NDE(t)] Step   72/500 | Loss=2.070543 | Jxx_eff=0.1079 (true 0.1000) | Jyy_eff=0.1900 (true 0.2000) | Jzz_eff=0.6864 (true 0.7000) | hx_eff=0.2956 (true 0.3000) | hz_eff=0.9818 (true 1.0000)
# [NDE(t)] Step   73/500 | Loss=2.070519 | Jxx_eff=0.1064 (true 0.1000) | Jyy_eff=0.1920 (true 0.2000) | Jzz_eff=0.6862 (true 0.7000) | hx_eff=0.2986 (true 0.3000) | hz_eff=0.9824 (true 1.0000)
# [NDE(t)] Step   74/500 | Loss=2.070531 | Jxx_eff=0.1063 (true 0.1000) | Jyy_eff=0.1949 (true 0.2000) | Jzz_eff=0.6858 (true 0.7000) | hx_eff=0.3010 (true 0.3000) | hz_eff=0.9821 (true 1.0000)
# [NDE(t)] Step   75/500 | Loss=2.070496 | Jxx_eff=0.1069 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6852 (true 0.7000) | hx_eff=0.3027 (true 0.3000) | hz_eff=0.9814 (true 1.0000)
# [NDE(t)] Step   76/500 | Loss=2.070513 | Jxx_eff=0.1076 (true 0.1000) | Jyy_eff=0.2009 (true 0.2000) | Jzz_eff=0.6847 (true 0.7000) | hx_eff=0.3036 (true 0.3000) | hz_eff=0.9808 (true 1.0000)
# [NDE(t)] Step   77/500 | Loss=2.070608 | Jxx_eff=0.1079 (true 0.1000) | Jyy_eff=0.2027 (true 0.2000) | Jzz_eff=0.6845 (true 0.7000) | hx_eff=0.3036 (true 0.3000) | hz_eff=0.9807 (true 1.0000)
# [NDE(t)] Step   78/500 | Loss=2.070676 | Jxx_eff=0.1073 (true 0.1000) | Jyy_eff=0.2033 (true 0.2000) | Jzz_eff=0.6847 (true 0.7000) | hx_eff=0.3030 (true 0.3000) | hz_eff=0.9815 (true 1.0000)
# [NDE(t)] Step   79/500 | Loss=2.070630 | Jxx_eff=0.1062 (true 0.1000) | Jyy_eff=0.2027 (true 0.2000) | Jzz_eff=0.6852 (true 0.7000) | hx_eff=0.3018 (true 0.3000) | hz_eff=0.9827 (true 1.0000)
# [NDE(t)] Step   80/500 | Loss=2.070526 | Jxx_eff=0.1051 (true 0.1000) | Jyy_eff=0.2015 (true 0.2000) | Jzz_eff=0.6860 (true 0.7000) | hx_eff=0.3001 (true 0.3000) | hz_eff=0.9839 (true 1.0000)
# [NDE(t)] Step   81/500 | Loss=2.070466 | Jxx_eff=0.1047 (true 0.1000) | Jyy_eff=0.2003 (true 0.2000) | Jzz_eff=0.6868 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9847 (true 1.0000)
# [NDE(t)] Step   82/500 | Loss=2.070457 | Jxx_eff=0.1052 (true 0.1000) | Jyy_eff=0.1994 (true 0.2000) | Jzz_eff=0.6875 (true 0.7000) | hx_eff=0.2964 (true 0.3000) | hz_eff=0.9848 (true 1.0000)
# [NDE(t)] Step   83/500 | Loss=2.070445 | Jxx_eff=0.1066 (true 0.1000) | Jyy_eff=0.1991 (true 0.2000) | Jzz_eff=0.6880 (true 0.7000) | hx_eff=0.2947 (true 0.3000) | hz_eff=0.9844 (true 1.0000)
# [NDE(t)] Step   84/500 | Loss=2.070424 | Jxx_eff=0.1086 (true 0.1000) | Jyy_eff=0.1990 (true 0.2000) | Jzz_eff=0.6882 (true 0.7000) | hx_eff=0.2934 (true 0.3000) | hz_eff=0.9838 (true 1.0000)
# [NDE(t)] Step   85/500 | Loss=2.070434 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1989 (true 0.2000) | Jzz_eff=0.6882 (true 0.7000) | hx_eff=0.2927 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step   86/500 | Loss=2.070468 | Jxx_eff=0.1117 (true 0.1000) | Jyy_eff=0.1984 (true 0.2000) | Jzz_eff=0.6882 (true 0.7000) | hx_eff=0.2926 (true 0.3000) | hz_eff=0.9839 (true 1.0000)
# [NDE(t)] Step   87/500 | Loss=2.070472 | Jxx_eff=0.1122 (true 0.1000) | Jyy_eff=0.1975 (true 0.2000) | Jzz_eff=0.6880 (true 0.7000) | hx_eff=0.2932 (true 0.3000) | hz_eff=0.9846 (true 1.0000)
# [NDE(t)] Step   88/500 | Loss=2.070436 | Jxx_eff=0.1123 (true 0.1000) | Jyy_eff=0.1963 (true 0.2000) | Jzz_eff=0.6878 (true 0.7000) | hx_eff=0.2942 (true 0.3000) | hz_eff=0.9853 (true 1.0000)
# [NDE(t)] Step   89/500 | Loss=2.070404 | Jxx_eff=0.1122 (true 0.1000) | Jyy_eff=0.1953 (true 0.2000) | Jzz_eff=0.6877 (true 0.7000) | hx_eff=0.2955 (true 0.3000) | hz_eff=0.9858 (true 1.0000)
# [NDE(t)] Step   90/500 | Loss=2.070399 | Jxx_eff=0.1123 (true 0.1000) | Jyy_eff=0.1947 (true 0.2000) | Jzz_eff=0.6875 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9857 (true 1.0000)
# [NDE(t)] Step   91/500 | Loss=2.070404 | Jxx_eff=0.1128 (true 0.1000) | Jyy_eff=0.1949 (true 0.2000) | Jzz_eff=0.6874 (true 0.7000) | hx_eff=0.2980 (true 0.3000) | hz_eff=0.9852 (true 1.0000)
# [NDE(t)] Step   92/500 | Loss=2.070402 | Jxx_eff=0.1134 (true 0.1000) | Jyy_eff=0.1955 (true 0.2000) | Jzz_eff=0.6874 (true 0.7000) | hx_eff=0.2988 (true 0.3000) | hz_eff=0.9846 (true 1.0000)
# [NDE(t)] Step   93/500 | Loss=2.070402 | Jxx_eff=0.1139 (true 0.1000) | Jyy_eff=0.1964 (true 0.2000) | Jzz_eff=0.6875 (true 0.7000) | hx_eff=0.2993 (true 0.3000) | hz_eff=0.9841 (true 1.0000)
# [NDE(t)] Step   94/500 | Loss=2.070413 | Jxx_eff=0.1139 (true 0.1000) | Jyy_eff=0.1969 (true 0.2000) | Jzz_eff=0.6876 (true 0.7000) | hx_eff=0.2993 (true 0.3000) | hz_eff=0.9841 (true 1.0000)
# [NDE(t)] Step   95/500 | Loss=2.070413 | Jxx_eff=0.1137 (true 0.1000) | Jyy_eff=0.1972 (true 0.2000) | Jzz_eff=0.6877 (true 0.7000) | hx_eff=0.2992 (true 0.3000) | hz_eff=0.9843 (true 1.0000)
# [NDE(t)] Step   96/500 | Loss=2.070406 | Jxx_eff=0.1132 (true 0.1000) | Jyy_eff=0.1974 (true 0.2000) | Jzz_eff=0.6879 (true 0.7000) | hx_eff=0.2989 (true 0.3000) | hz_eff=0.9845 (true 1.0000)
# [NDE(t)] Step   97/500 | Loss=2.070393 | Jxx_eff=0.1126 (true 0.1000) | Jyy_eff=0.1976 (true 0.2000) | Jzz_eff=0.6881 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9848 (true 1.0000)
# [NDE(t)] Step   98/500 | Loss=2.070381 | Jxx_eff=0.1119 (true 0.1000) | Jyy_eff=0.1976 (true 0.2000) | Jzz_eff=0.6883 (true 0.7000) | hx_eff=0.2980 (true 0.3000) | hz_eff=0.9849 (true 1.0000)
# [NDE(t)] Step   99/500 | Loss=2.070374 | Jxx_eff=0.1112 (true 0.1000) | Jyy_eff=0.1977 (true 0.2000) | Jzz_eff=0.6885 (true 0.7000) | hx_eff=0.2975 (true 0.3000) | hz_eff=0.9850 (true 1.0000)
# [NDE(t)] Step  100/500 | Loss=2.070370 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1978 (true 0.2000) | Jzz_eff=0.6886 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9849 (true 1.0000)
# [NDE(t)] Step  101/500 | Loss=2.070368 | Jxx_eff=0.1103 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6888 (true 0.7000) | hx_eff=0.2964 (true 0.3000) | hz_eff=0.9846 (true 1.0000)
# [NDE(t)] Step  102/500 | Loss=2.070367 | Jxx_eff=0.1100 (true 0.1000) | Jyy_eff=0.1983 (true 0.2000) | Jzz_eff=0.6889 (true 0.7000) | hx_eff=0.2960 (true 0.3000) | hz_eff=0.9843 (true 1.0000)
# [NDE(t)] Step  103/500 | Loss=2.070367 | Jxx_eff=0.1100 (true 0.1000) | Jyy_eff=0.1986 (true 0.2000) | Jzz_eff=0.6890 (true 0.7000) | hx_eff=0.2956 (true 0.3000) | hz_eff=0.9840 (true 1.0000)
# [NDE(t)] Step  104/500 | Loss=2.070369 | Jxx_eff=0.1099 (true 0.1000) | Jyy_eff=0.1990 (true 0.2000) | Jzz_eff=0.6890 (true 0.7000) | hx_eff=0.2954 (true 0.3000) | hz_eff=0.9838 (true 1.0000)
# [NDE(t)] Step  105/500 | Loss=2.070372 | Jxx_eff=0.1099 (true 0.1000) | Jyy_eff=0.1992 (true 0.2000) | Jzz_eff=0.6891 (true 0.7000) | hx_eff=0.2953 (true 0.3000) | hz_eff=0.9837 (true 1.0000)
# [NDE(t)] Step  106/500 | Loss=2.070374 | Jxx_eff=0.1099 (true 0.1000) | Jyy_eff=0.1994 (true 0.2000) | Jzz_eff=0.6892 (true 0.7000) | hx_eff=0.2954 (true 0.3000) | hz_eff=0.9837 (true 1.0000)
# [NDE(t)] Step  107/500 | Loss=2.070374 | Jxx_eff=0.1099 (true 0.1000) | Jyy_eff=0.1995 (true 0.2000) | Jzz_eff=0.6893 (true 0.7000) | hx_eff=0.2955 (true 0.3000) | hz_eff=0.9838 (true 1.0000)
# [NDE(t)] Step  108/500 | Loss=2.070371 | Jxx_eff=0.1098 (true 0.1000) | Jyy_eff=0.1994 (true 0.2000) | Jzz_eff=0.6893 (true 0.7000) | hx_eff=0.2958 (true 0.3000) | hz_eff=0.9840 (true 1.0000)
# [NDE(t)] Step  109/500 | Loss=2.070368 | Jxx_eff=0.1097 (true 0.1000) | Jyy_eff=0.1993 (true 0.2000) | Jzz_eff=0.6894 (true 0.7000) | hx_eff=0.2961 (true 0.3000) | hz_eff=0.9841 (true 1.0000)
# [NDE(t)] Step  110/500 | Loss=2.070365 | Jxx_eff=0.1097 (true 0.1000) | Jyy_eff=0.1990 (true 0.2000) | Jzz_eff=0.6893 (true 0.7000) | hx_eff=0.2965 (true 0.3000) | hz_eff=0.9841 (true 1.0000)
# [NDE(t)] Step  111/500 | Loss=2.070363 | Jxx_eff=0.1097 (true 0.1000) | Jyy_eff=0.1988 (true 0.2000) | Jzz_eff=0.6893 (true 0.7000) | hx_eff=0.2968 (true 0.3000) | hz_eff=0.9840 (true 1.0000)
# [NDE(t)] Step  112/500 | Loss=2.070362 | Jxx_eff=0.1098 (true 0.1000) | Jyy_eff=0.1986 (true 0.2000) | Jzz_eff=0.6893 (true 0.7000) | hx_eff=0.2971 (true 0.3000) | hz_eff=0.9839 (true 1.0000)
# [NDE(t)] Step  113/500 | Loss=2.070361 | Jxx_eff=0.1100 (true 0.1000) | Jyy_eff=0.1985 (true 0.2000) | Jzz_eff=0.6892 (true 0.7000) | hx_eff=0.2974 (true 0.3000) | hz_eff=0.9837 (true 1.0000)
# [NDE(t)] Step  114/500 | Loss=2.070361 | Jxx_eff=0.1102 (true 0.1000) | Jyy_eff=0.1983 (true 0.2000) | Jzz_eff=0.6891 (true 0.7000) | hx_eff=0.2975 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  115/500 | Loss=2.070361 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1983 (true 0.2000) | Jzz_eff=0.6891 (true 0.7000) | hx_eff=0.2976 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  116/500 | Loss=2.070361 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1983 (true 0.2000) | Jzz_eff=0.6891 (true 0.7000) | hx_eff=0.2976 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  117/500 | Loss=2.070361 | Jxx_eff=0.1106 (true 0.1000) | Jyy_eff=0.1983 (true 0.2000) | Jzz_eff=0.6891 (true 0.7000) | hx_eff=0.2976 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  118/500 | Loss=2.070361 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1982 (true 0.2000) | Jzz_eff=0.6891 (true 0.7000) | hx_eff=0.2976 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  119/500 | Loss=2.070360 | Jxx_eff=0.1108 (true 0.1000) | Jyy_eff=0.1982 (true 0.2000) | Jzz_eff=0.6891 (true 0.7000) | hx_eff=0.2975 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  120/500 | Loss=2.070360 | Jxx_eff=0.1108 (true 0.1000) | Jyy_eff=0.1982 (true 0.2000) | Jzz_eff=0.6891 (true 0.7000) | hx_eff=0.2975 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  121/500 | Loss=2.070359 | Jxx_eff=0.1109 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6892 (true 0.7000) | hx_eff=0.2974 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  122/500 | Loss=2.070359 | Jxx_eff=0.1109 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6892 (true 0.7000) | hx_eff=0.2973 (true 0.3000) | hz_eff=0.9837 (true 1.0000)
# [NDE(t)] Step  123/500 | Loss=2.070358 | Jxx_eff=0.1108 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6893 (true 0.7000) | hx_eff=0.2972 (true 0.3000) | hz_eff=0.9837 (true 1.0000)
# [NDE(t)] Step  124/500 | Loss=2.070358 | Jxx_eff=0.1108 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6893 (true 0.7000) | hx_eff=0.2971 (true 0.3000) | hz_eff=0.9837 (true 1.0000)
# [NDE(t)] Step  125/500 | Loss=2.070358 | Jxx_eff=0.1108 (true 0.1000) | Jyy_eff=0.1978 (true 0.2000) | Jzz_eff=0.6893 (true 0.7000) | hx_eff=0.2970 (true 0.3000) | hz_eff=0.9837 (true 1.0000)
# [NDE(t)] Step  126/500 | Loss=2.070357 | Jxx_eff=0.1108 (true 0.1000) | Jyy_eff=0.1977 (true 0.2000) | Jzz_eff=0.6894 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9837 (true 1.0000)
# [NDE(t)] Step  127/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1977 (true 0.2000) | Jzz_eff=0.6894 (true 0.7000) | hx_eff=0.2968 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  128/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1976 (true 0.2000) | Jzz_eff=0.6894 (true 0.7000) | hx_eff=0.2967 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  129/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1976 (true 0.2000) | Jzz_eff=0.6894 (true 0.7000) | hx_eff=0.2966 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  130/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1976 (true 0.2000) | Jzz_eff=0.6894 (true 0.7000) | hx_eff=0.2966 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  131/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1977 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2966 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  132/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1977 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2965 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  133/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1978 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2965 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  134/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1978 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2965 (true 0.3000) | hz_eff=0.9835 (true 1.0000)
# [NDE(t)] Step  135/500 | Loss=2.070357 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1978 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2966 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  136/500 | Loss=2.070356 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2966 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  137/500 | Loss=2.070356 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2966 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  138/500 | Loss=2.070356 | Jxx_eff=0.1107 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2966 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  139/500 | Loss=2.070356 | Jxx_eff=0.1106 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2967 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  140/500 | Loss=2.070356 | Jxx_eff=0.1106 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2967 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  141/500 | Loss=2.070356 | Jxx_eff=0.1106 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2967 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  142/500 | Loss=2.070356 | Jxx_eff=0.1106 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2968 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  143/500 | Loss=2.070356 | Jxx_eff=0.1106 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2968 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  144/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1979 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2968 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  145/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2968 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  146/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  147/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  148/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  149/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  150/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  151/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1980 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  152/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  153/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2970 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  154/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2970 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  155/500 | Loss=2.070355 | Jxx_eff=0.1105 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2970 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  156/500 | Loss=2.070355 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  157/500 | Loss=2.070355 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  158/500 | Loss=2.070355 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  159/500 | Loss=2.070355 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  160/500 | Loss=2.070355 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  161/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  162/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  163/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  164/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  165/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  166/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  167/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  168/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  169/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [NDE(t)] Step  170/500 | Loss=2.070354 | Jxx_eff=0.1104 (true 0.1000) | Jyy_eff=0.1981 (true 0.2000) | Jzz_eff=0.6895 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9836 (true 1.0000)
# [EarlyStopping] Parando en step 170 porque la loss no mejora (min_delta=1e-05) en 50 iteraciones. Best=2.070360
# [NDE(t)] Step    1/500 | Loss=3.021279 | Jxx_eff=0.8515 (true 0.1000) | Jyy_eff=0.8759 (true 0.2000) | Jzz_eff=0.4069 (true 0.7000) | hx_eff=0.7609 (true 0.3000) | hz_eff=0.9885 (true 1.0000)
# [NDE(t)] Step    2/500 | Loss=2.936639 | Jxx_eff=0.8197 (true 0.1000) | Jyy_eff=0.8776 (true 0.2000) | Jzz_eff=0.4396 (true 0.7000) | hx_eff=0.6815 (true 0.3000) | hz_eff=1.0450 (true 1.0000)
# [NDE(t)] Step    3/500 | Loss=2.871323 | Jxx_eff=0.7864 (true 0.1000) | Jyy_eff=0.8986 (true 0.2000) | Jzz_eff=0.4382 (true 0.7000) | hx_eff=0.5987 (true 0.3000) | hz_eff=1.0786 (true 1.0000)
# [NDE(t)] Step    4/500 | Loss=2.817804 | Jxx_eff=0.7598 (true 0.1000) | Jyy_eff=0.9118 (true 0.2000) | Jzz_eff=0.4137 (true 0.7000) | hx_eff=0.5145 (true 0.3000) | hz_eff=1.1019 (true 1.0000)
# [NDE(t)] Step    5/500 | Loss=2.787874 | Jxx_eff=0.7568 (true 0.1000) | Jyy_eff=0.9403 (true 0.2000) | Jzz_eff=0.3842 (true 0.7000) | hx_eff=0.4447 (true 0.3000) | hz_eff=1.0991 (true 1.0000)
# [NDE(t)] Step    6/500 | Loss=2.806282 | Jxx_eff=0.7466 (true 0.1000) | Jyy_eff=0.9354 (true 0.2000) | Jzz_eff=0.3889 (true 0.7000) | hx_eff=0.4123 (true 0.3000) | hz_eff=1.1135 (true 1.0000)
# [NDE(t)] Step    7/500 | Loss=2.804771 | Jxx_eff=0.7231 (true 0.1000) | Jyy_eff=0.9302 (true 0.2000) | Jzz_eff=0.4267 (true 0.7000) | hx_eff=0.3884 (true 0.3000) | hz_eff=1.1460 (true 1.0000)
# [NDE(t)] Step    8/500 | Loss=2.754930 | Jxx_eff=0.6920 (true 0.1000) | Jyy_eff=0.9213 (true 0.2000) | Jzz_eff=0.4831 (true 0.7000) | hx_eff=0.3648 (true 0.3000) | hz_eff=1.1869 (true 1.0000)
# [NDE(t)] Step    9/500 | Loss=2.712025 | Jxx_eff=0.6595 (true 0.1000) | Jyy_eff=0.9195 (true 0.2000) | Jzz_eff=0.5428 (true 0.7000) | hx_eff=0.3339 (true 0.3000) | hz_eff=1.2139 (true 1.0000)
# [NDE(t)] Step   10/500 | Loss=2.712249 | Jxx_eff=0.6411 (true 0.1000) | Jyy_eff=0.9269 (true 0.2000) | Jzz_eff=0.6042 (true 0.7000) | hx_eff=0.3015 (true 0.3000) | hz_eff=1.2277 (true 1.0000)
# [NDE(t)] Step   11/500 | Loss=2.712128 | Jxx_eff=0.6473 (true 0.1000) | Jyy_eff=0.9542 (true 0.2000) | Jzz_eff=0.6505 (true 0.7000) | hx_eff=0.2746 (true 0.3000) | hz_eff=1.2243 (true 1.0000)
# [NDE(t)] Step   12/500 | Loss=2.717846 | Jxx_eff=0.6654 (true 0.1000) | Jyy_eff=0.9903 (true 0.2000) | Jzz_eff=0.6688 (true 0.7000) | hx_eff=0.2572 (true 0.3000) | hz_eff=1.2096 (true 1.0000)
# [NDE(t)] Step   13/500 | Loss=2.715979 | Jxx_eff=0.6878 (true 0.1000) | Jyy_eff=1.0260 (true 0.2000) | Jzz_eff=0.6725 (true 0.7000) | hx_eff=0.2506 (true 0.3000) | hz_eff=1.2010 (true 1.0000)
# [NDE(t)] Step   14/500 | Loss=2.711784 | Jxx_eff=0.7086 (true 0.1000) | Jyy_eff=1.0569 (true 0.2000) | Jzz_eff=0.6682 (true 0.7000) | hx_eff=0.2529 (true 0.3000) | hz_eff=1.2129 (true 1.0000)
# [NDE(t)] Step   15/500 | Loss=2.711848 | Jxx_eff=0.7299 (true 0.1000) | Jyy_eff=1.0736 (true 0.2000) | Jzz_eff=0.6591 (true 0.7000) | hx_eff=0.2623 (true 0.3000) | hz_eff=1.2221 (true 1.0000)
# [NDE(t)] Step   16/500 | Loss=2.709844 | Jxx_eff=0.7444 (true 0.1000) | Jyy_eff=1.0776 (true 0.2000) | Jzz_eff=0.6522 (true 0.7000) | hx_eff=0.2770 (true 0.3000) | hz_eff=1.2401 (true 1.0000)
# [NDE(t)] Step   17/500 | Loss=2.707972 | Jxx_eff=0.7497 (true 0.1000) | Jyy_eff=1.0696 (true 0.2000) | Jzz_eff=0.6482 (true 0.7000) | hx_eff=0.2952 (true 0.3000) | hz_eff=1.2588 (true 1.0000)
# [NDE(t)] Step   18/500 | Loss=2.703297 | Jxx_eff=0.7500 (true 0.1000) | Jyy_eff=1.0557 (true 0.2000) | Jzz_eff=0.6416 (true 0.7000) | hx_eff=0.3118 (true 0.3000) | hz_eff=1.2840 (true 1.0000)
# [NDE(t)] Step   19/500 | Loss=2.699114 | Jxx_eff=0.7544 (true 0.1000) | Jyy_eff=1.0494 (true 0.2000) | Jzz_eff=0.6280 (true 0.7000) | hx_eff=0.3261 (true 0.3000) | hz_eff=1.3053 (true 1.0000)
# [NDE(t)] Step   20/500 | Loss=2.696261 | Jxx_eff=0.7572 (true 0.1000) | Jyy_eff=1.0394 (true 0.2000) | Jzz_eff=0.6153 (true 0.7000) | hx_eff=0.3392 (true 0.3000) | hz_eff=1.3338 (true 1.0000)
# [NDE(t)] Step   21/500 | Loss=2.700363 | Jxx_eff=0.7590 (true 0.1000) | Jyy_eff=1.0314 (true 0.2000) | Jzz_eff=0.6046 (true 0.7000) | hx_eff=0.3482 (true 0.3000) | hz_eff=1.3439 (true 1.0000)
# [NDE(t)] Step   22/500 | Loss=2.705604 | Jxx_eff=0.7603 (true 0.1000) | Jyy_eff=1.0245 (true 0.2000) | Jzz_eff=0.6000 (true 0.7000) | hx_eff=0.3520 (true 0.3000) | hz_eff=1.3380 (true 1.0000)
# [NDE(t)] Step   23/500 | Loss=2.705268 | Jxx_eff=0.7670 (true 0.1000) | Jyy_eff=1.0247 (true 0.2000) | Jzz_eff=0.5930 (true 0.7000) | hx_eff=0.3540 (true 0.3000) | hz_eff=1.3106 (true 1.0000)
# [NDE(t)] Step   24/500 | Loss=2.701744 | Jxx_eff=0.7688 (true 0.1000) | Jyy_eff=1.0210 (true 0.2000) | Jzz_eff=0.5931 (true 0.7000) | hx_eff=0.3517 (true 0.3000) | hz_eff=1.2817 (true 1.0000)
# [NDE(t)] Step   25/500 | Loss=2.701731 | Jxx_eff=0.7634 (true 0.1000) | Jyy_eff=1.0148 (true 0.2000) | Jzz_eff=0.5993 (true 0.7000) | hx_eff=0.3431 (true 0.3000) | hz_eff=1.2699 (true 1.0000)
# [NDE(t)] Step   26/500 | Loss=2.700556 | Jxx_eff=0.7538 (true 0.1000) | Jyy_eff=1.0060 (true 0.2000) | Jzz_eff=0.6131 (true 0.7000) | hx_eff=0.3320 (true 0.3000) | hz_eff=1.2709 (true 1.0000)
# [NDE(t)] Step   27/500 | Loss=2.697467 | Jxx_eff=0.7489 (true 0.1000) | Jyy_eff=1.0027 (true 0.2000) | Jzz_eff=0.6257 (true 0.7000) | hx_eff=0.3177 (true 0.3000) | hz_eff=1.2757 (true 1.0000)
# [NDE(t)] Step   28/500 | Loss=2.697541 | Jxx_eff=0.7511 (true 0.1000) | Jyy_eff=1.0078 (true 0.2000) | Jzz_eff=0.6330 (true 0.7000) | hx_eff=0.3022 (true 0.3000) | hz_eff=1.2825 (true 1.0000)
# [NDE(t)] Step   29/500 | Loss=2.695443 | Jxx_eff=0.7588 (true 0.1000) | Jyy_eff=1.0192 (true 0.2000) | Jzz_eff=0.6356 (true 0.7000) | hx_eff=0.2877 (true 0.3000) | hz_eff=1.2873 (true 1.0000)
# [NDE(t)] Step   30/500 | Loss=2.694693 | Jxx_eff=0.7629 (true 0.1000) | Jyy_eff=1.0266 (true 0.2000) | Jzz_eff=0.6346 (true 0.7000) | hx_eff=0.2777 (true 0.3000) | hz_eff=1.2881 (true 1.0000)
# [NDE(t)] Step   31/500 | Loss=2.698760 | Jxx_eff=0.7594 (true 0.1000) | Jyy_eff=1.0254 (true 0.2000) | Jzz_eff=0.6347 (true 0.7000) | hx_eff=0.2771 (true 0.3000) | hz_eff=1.2831 (true 1.0000)
# [NDE(t)] Step   32/500 | Loss=2.698754 | Jxx_eff=0.7463 (true 0.1000) | Jyy_eff=1.0139 (true 0.2000) | Jzz_eff=0.6344 (true 0.7000) | hx_eff=0.2857 (true 0.3000) | hz_eff=1.2751 (true 1.0000)
# [NDE(t)] Step   33/500 | Loss=2.694340 | Jxx_eff=0.7346 (true 0.1000) | Jyy_eff=1.0030 (true 0.2000) | Jzz_eff=0.6317 (true 0.7000) | hx_eff=0.2991 (true 0.3000) | hz_eff=1.2664 (true 1.0000)
# [NDE(t)] Step   34/500 | Loss=2.694524 | Jxx_eff=0.7298 (true 0.1000) | Jyy_eff=0.9984 (true 0.2000) | Jzz_eff=0.6263 (true 0.7000) | hx_eff=0.3141 (true 0.3000) | hz_eff=1.2572 (true 1.0000)
# [NDE(t)] Step   35/500 | Loss=2.693610 | Jxx_eff=0.7290 (true 0.1000) | Jyy_eff=0.9979 (true 0.2000) | Jzz_eff=0.6186 (true 0.7000) | hx_eff=0.3290 (true 0.3000) | hz_eff=1.2484 (true 1.0000)
# [NDE(t)] Step   36/500 | Loss=2.691757 | Jxx_eff=0.7318 (true 0.1000) | Jyy_eff=1.0012 (true 0.2000) | Jzz_eff=0.6095 (true 0.7000) | hx_eff=0.3408 (true 0.3000) | hz_eff=1.2437 (true 1.0000)
# [NDE(t)] Step   37/500 | Loss=2.690446 | Jxx_eff=0.7351 (true 0.1000) | Jyy_eff=1.0038 (true 0.2000) | Jzz_eff=0.6035 (true 0.7000) | hx_eff=0.3492 (true 0.3000) | hz_eff=1.2392 (true 1.0000)
# [NDE(t)] Step   38/500 | Loss=2.691473 | Jxx_eff=0.7359 (true 0.1000) | Jyy_eff=1.0042 (true 0.2000) | Jzz_eff=0.6005 (true 0.7000) | hx_eff=0.3540 (true 0.3000) | hz_eff=1.2325 (true 1.0000)
# [NDE(t)] Step   39/500 | Loss=2.692353 | Jxx_eff=0.7321 (true 0.1000) | Jyy_eff=1.0023 (true 0.2000) | Jzz_eff=0.6002 (true 0.7000) | hx_eff=0.3532 (true 0.3000) | hz_eff=1.2264 (true 1.0000)
# [NDE(t)] Step   40/500 | Loss=2.691709 | Jxx_eff=0.7247 (true 0.1000) | Jyy_eff=0.9988 (true 0.2000) | Jzz_eff=0.6019 (true 0.7000) | hx_eff=0.3472 (true 0.3000) | hz_eff=1.2209 (true 1.0000)
# [NDE(t)] Step   41/500 | Loss=2.689932 | Jxx_eff=0.7156 (true 0.1000) | Jyy_eff=0.9934 (true 0.2000) | Jzz_eff=0.6046 (true 0.7000) | hx_eff=0.3376 (true 0.3000) | hz_eff=1.2162 (true 1.0000)
# [NDE(t)] Step   42/500 | Loss=2.688104 | Jxx_eff=0.7078 (true 0.1000) | Jyy_eff=0.9875 (true 0.2000) | Jzz_eff=0.6076 (true 0.7000) | hx_eff=0.3252 (true 0.3000) | hz_eff=1.2140 (true 1.0000)
# [NDE(t)] Step   43/500 | Loss=2.687517 | Jxx_eff=0.7049 (true 0.1000) | Jyy_eff=0.9837 (true 0.2000) | Jzz_eff=0.6115 (true 0.7000) | hx_eff=0.3128 (true 0.3000) | hz_eff=1.2151 (true 1.0000)
# [NDE(t)] Step   44/500 | Loss=2.687215 | Jxx_eff=0.7070 (true 0.1000) | Jyy_eff=0.9820 (true 0.2000) | Jzz_eff=0.6156 (true 0.7000) | hx_eff=0.3038 (true 0.3000) | hz_eff=1.2164 (true 1.0000)
# [NDE(t)] Step   45/500 | Loss=2.686882 | Jxx_eff=0.7107 (true 0.1000) | Jyy_eff=0.9783 (true 0.2000) | Jzz_eff=0.6185 (true 0.7000) | hx_eff=0.3003 (true 0.3000) | hz_eff=1.2132 (true 1.0000)
# [NDE(t)] Step   46/500 | Loss=2.686977 | Jxx_eff=0.7126 (true 0.1000) | Jyy_eff=0.9695 (true 0.2000) | Jzz_eff=0.6190 (true 0.7000) | hx_eff=0.3026 (true 0.3000) | hz_eff=1.2041 (true 1.0000)
# [NDE(t)] Step   47/500 | Loss=2.686283 | Jxx_eff=0.7125 (true 0.1000) | Jyy_eff=0.9569 (true 0.2000) | Jzz_eff=0.6177 (true 0.7000) | hx_eff=0.3104 (true 0.3000) | hz_eff=1.1907 (true 1.0000)
# [NDE(t)] Step   48/500 | Loss=2.685250 | Jxx_eff=0.7115 (true 0.1000) | Jyy_eff=0.9444 (true 0.2000) | Jzz_eff=0.6144 (true 0.7000) | hx_eff=0.3211 (true 0.3000) | hz_eff=1.1794 (true 1.0000)
# [NDE(t)] Step   49/500 | Loss=2.684352 | Jxx_eff=0.7106 (true 0.1000) | Jyy_eff=0.9346 (true 0.2000) | Jzz_eff=0.6097 (true 0.7000) | hx_eff=0.3325 (true 0.3000) | hz_eff=1.1721 (true 1.0000)
# [NDE(t)] Step   50/500 | Loss=2.683533 | Jxx_eff=0.7094 (true 0.1000) | Jyy_eff=0.9261 (true 0.2000) | Jzz_eff=0.6049 (true 0.7000) | hx_eff=0.3429 (true 0.3000) | hz_eff=1.1650 (true 1.0000)
# [NDE(t)] Step   51/500 | Loss=2.683501 | Jxx_eff=0.7067 (true 0.1000) | Jyy_eff=0.9174 (true 0.2000) | Jzz_eff=0.6018 (true 0.7000) | hx_eff=0.3510 (true 0.3000) | hz_eff=1.1555 (true 1.0000)
# [NDE(t)] Step   52/500 | Loss=2.683598 | Jxx_eff=0.7030 (true 0.1000) | Jyy_eff=0.9079 (true 0.2000) | Jzz_eff=0.6013 (true 0.7000) | hx_eff=0.3568 (true 0.3000) | hz_eff=1.1428 (true 1.0000)
# [NDE(t)] Step   53/500 | Loss=2.683167 | Jxx_eff=0.6996 (true 0.1000) | Jyy_eff=0.9002 (true 0.2000) | Jzz_eff=0.6030 (true 0.7000) | hx_eff=0.3604 (true 0.3000) | hz_eff=1.1291 (true 1.0000)
# [NDE(t)] Step   54/500 | Loss=2.682785 | Jxx_eff=0.6976 (true 0.1000) | Jyy_eff=0.8997 (true 0.2000) | Jzz_eff=0.6058 (true 0.7000) | hx_eff=0.3632 (true 0.3000) | hz_eff=1.1217 (true 1.0000)
# [NDE(t)] Step   55/500 | Loss=2.682129 | Jxx_eff=0.6956 (true 0.1000) | Jyy_eff=0.9027 (true 0.2000) | Jzz_eff=0.6081 (true 0.7000) | hx_eff=0.3644 (true 0.3000) | hz_eff=1.1173 (true 1.0000)
# [NDE(t)] Step   56/500 | Loss=2.681818 | Jxx_eff=0.6896 (true 0.1000) | Jyy_eff=0.9030 (true 0.2000) | Jzz_eff=0.6095 (true 0.7000) | hx_eff=0.3634 (true 0.3000) | hz_eff=1.1114 (true 1.0000)
# [NDE(t)] Step   57/500 | Loss=2.681182 | Jxx_eff=0.6804 (true 0.1000) | Jyy_eff=0.8997 (true 0.2000) | Jzz_eff=0.6104 (true 0.7000) | hx_eff=0.3618 (true 0.3000) | hz_eff=1.1028 (true 1.0000)
# [NDE(t)] Step   58/500 | Loss=2.679956 | Jxx_eff=0.6705 (true 0.1000) | Jyy_eff=0.8950 (true 0.2000) | Jzz_eff=0.6127 (true 0.7000) | hx_eff=0.3581 (true 0.3000) | hz_eff=1.0950 (true 1.0000)
# [NDE(t)] Step   59/500 | Loss=2.678377 | Jxx_eff=0.6613 (true 0.1000) | Jyy_eff=0.8867 (true 0.2000) | Jzz_eff=0.6157 (true 0.7000) | hx_eff=0.3546 (true 0.3000) | hz_eff=1.0843 (true 1.0000)
# [NDE(t)] Step   60/500 | Loss=2.677582 | Jxx_eff=0.6550 (true 0.1000) | Jyy_eff=0.8755 (true 0.2000) | Jzz_eff=0.6188 (true 0.7000) | hx_eff=0.3537 (true 0.3000) | hz_eff=1.0690 (true 1.0000)
# [NDE(t)] Step   61/500 | Loss=2.677343 | Jxx_eff=0.6539 (true 0.1000) | Jyy_eff=0.8670 (true 0.2000) | Jzz_eff=0.6234 (true 0.7000) | hx_eff=0.3537 (true 0.3000) | hz_eff=1.0563 (true 1.0000)
# [NDE(t)] Step   62/500 | Loss=2.676315 | Jxx_eff=0.6566 (true 0.1000) | Jyy_eff=0.8581 (true 0.2000) | Jzz_eff=0.6289 (true 0.7000) | hx_eff=0.3563 (true 0.3000) | hz_eff=1.0428 (true 1.0000)
# [NDE(t)] Step   63/500 | Loss=2.674805 | Jxx_eff=0.6606 (true 0.1000) | Jyy_eff=0.8438 (true 0.2000) | Jzz_eff=0.6343 (true 0.7000) | hx_eff=0.3637 (true 0.3000) | hz_eff=1.0236 (true 1.0000)
# [NDE(t)] Step   64/500 | Loss=2.672873 | Jxx_eff=0.6662 (true 0.1000) | Jyy_eff=0.8230 (true 0.2000) | Jzz_eff=0.6401 (true 0.7000) | hx_eff=0.3735 (true 0.3000) | hz_eff=0.9965 (true 1.0000)
# [NDE(t)] Step   65/500 | Loss=2.670308 | Jxx_eff=0.6709 (true 0.1000) | Jyy_eff=0.7987 (true 0.2000) | Jzz_eff=0.6466 (true 0.7000) | hx_eff=0.3801 (true 0.3000) | hz_eff=0.9705 (true 1.0000)
# [NDE(t)] Step   66/500 | Loss=2.669408 | Jxx_eff=0.6756 (true 0.1000) | Jyy_eff=0.7835 (true 0.2000) | Jzz_eff=0.6545 (true 0.7000) | hx_eff=0.3746 (true 0.3000) | hz_eff=0.9584 (true 1.0000)
# [NDE(t)] Step   67/500 | Loss=2.667865 | Jxx_eff=0.6801 (true 0.1000) | Jyy_eff=0.7777 (true 0.2000) | Jzz_eff=0.6625 (true 0.7000) | hx_eff=0.3595 (true 0.3000) | hz_eff=0.9572 (true 1.0000)
# [NDE(t)] Step   68/500 | Loss=2.665475 | Jxx_eff=0.6834 (true 0.1000) | Jyy_eff=0.7713 (true 0.2000) | Jzz_eff=0.6681 (true 0.7000) | hx_eff=0.3434 (true 0.3000) | hz_eff=0.9529 (true 1.0000)
# [NDE(t)] Step   69/500 | Loss=2.664301 | Jxx_eff=0.6856 (true 0.1000) | Jyy_eff=0.7583 (true 0.2000) | Jzz_eff=0.6711 (true 0.7000) | hx_eff=0.3318 (true 0.3000) | hz_eff=0.9372 (true 1.0000)
# [NDE(t)] Step   70/500 | Loss=2.661813 | Jxx_eff=0.6878 (true 0.1000) | Jyy_eff=0.7411 (true 0.2000) | Jzz_eff=0.6726 (true 0.7000) | hx_eff=0.3235 (true 0.3000) | hz_eff=0.9139 (true 1.0000)
# [NDE(t)] Step   71/500 | Loss=2.659801 | Jxx_eff=0.6905 (true 0.1000) | Jyy_eff=0.7282 (true 0.2000) | Jzz_eff=0.6750 (true 0.7000) | hx_eff=0.3141 (true 0.3000) | hz_eff=0.8966 (true 1.0000)
# [NDE(t)] Step   72/500 | Loss=2.659187 | Jxx_eff=0.6943 (true 0.1000) | Jyy_eff=0.7230 (true 0.2000) | Jzz_eff=0.6791 (true 0.7000) | hx_eff=0.3029 (true 0.3000) | hz_eff=0.8900 (true 1.0000)
# [NDE(t)] Step   73/500 | Loss=2.657686 | Jxx_eff=0.6992 (true 0.1000) | Jyy_eff=0.7183 (true 0.2000) | Jzz_eff=0.6847 (true 0.7000) | hx_eff=0.2940 (true 0.3000) | hz_eff=0.8857 (true 1.0000)
# [NDE(t)] Step   74/500 | Loss=2.657085 | Jxx_eff=0.7050 (true 0.1000) | Jyy_eff=0.7097 (true 0.2000) | Jzz_eff=0.6909 (true 0.7000) | hx_eff=0.2901 (true 0.3000) | hz_eff=0.8767 (true 1.0000)
# [NDE(t)] Step   75/500 | Loss=2.656183 | Jxx_eff=0.7110 (true 0.1000) | Jyy_eff=0.6978 (true 0.2000) | Jzz_eff=0.6970 (true 0.7000) | hx_eff=0.2902 (true 0.3000) | hz_eff=0.8642 (true 1.0000)
# [NDE(t)] Step   76/500 | Loss=2.654990 | Jxx_eff=0.7170 (true 0.1000) | Jyy_eff=0.6870 (true 0.2000) | Jzz_eff=0.7036 (true 0.7000) | hx_eff=0.2919 (true 0.3000) | hz_eff=0.8537 (true 1.0000)
# [NDE(t)] Step   77/500 | Loss=2.653884 | Jxx_eff=0.7242 (true 0.1000) | Jyy_eff=0.6802 (true 0.2000) | Jzz_eff=0.7106 (true 0.7000) | hx_eff=0.2944 (true 0.3000) | hz_eff=0.8486 (true 1.0000)
# [NDE(t)] Step   78/500 | Loss=2.652925 | Jxx_eff=0.7316 (true 0.1000) | Jyy_eff=0.6767 (true 0.2000) | Jzz_eff=0.7191 (true 0.7000) | hx_eff=0.2965 (true 0.3000) | hz_eff=0.8467 (true 1.0000)
# [NDE(t)] Step   79/500 | Loss=2.652585 | Jxx_eff=0.7341 (true 0.1000) | Jyy_eff=0.6660 (true 0.2000) | Jzz_eff=0.7266 (true 0.7000) | hx_eff=0.2989 (true 0.3000) | hz_eff=0.8413 (true 1.0000)
# ...
# [NDE(t)] Step  132/500 | Loss=2.070304 | Jxx_eff=0.1068 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6996 (true 0.7000) | hx_eff=0.2956 (true 0.3000) | hz_eff=0.9888 (true 1.0000)
# [NDE(t)] Step  133/500 | Loss=2.070299 | Jxx_eff=0.1068 (true 0.1000) | Jyy_eff=0.1959 (true 0.2000) | Jzz_eff=0.6992 (true 0.7000) | hx_eff=0.2954 (true 0.3000) | hz_eff=0.9898 (true 1.0000)
# [NDE(t)] Step  134/500 | Loss=2.070296 | Jxx_eff=0.1072 (true 0.1000) | Jyy_eff=0.1954 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2956 (true 0.3000) | hz_eff=0.9906 (true 1.0000)
# [NDE(t)] Step  135/500 | Loss=2.070298 | Jxx_eff=0.1077 (true 0.1000) | Jyy_eff=0.1952 (true 0.2000) | Jzz_eff=0.6984 (true 0.7000) | hx_eff=0.2961 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step  136/500 | Loss=2.070293 | Jxx_eff=0.1084 (true 0.1000) | Jyy_eff=0.1952 (true 0.2000) | Jzz_eff=0.6985 (true 0.7000) | hx_eff=0.2969 (true 0.3000) | hz_eff=0.9903 (true 1.0000)
# [NDE(t)] Step  137/500 | Loss=2.070285 | Jxx_eff=0.1087 (true 0.1000) | Jyy_eff=0.1952 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2977 (true 0.3000) | hz_eff=0.9898 (true 1.0000)
# [NDE(t)] Step  138/500 | Loss=2.070286 | Jxx_eff=0.1087 (true 0.1000) | Jyy_eff=0.1951 (true 0.2000) | Jzz_eff=0.6989 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9896 (true 1.0000)
# [NDE(t)] Step  139/500 | Loss=2.070291 | Jxx_eff=0.1082 (true 0.1000) | Jyy_eff=0.1949 (true 0.2000) | Jzz_eff=0.6989 (true 0.7000) | hx_eff=0.2988 (true 0.3000) | hz_eff=0.9898 (true 1.0000)
# [NDE(t)] Step  140/500 | Loss=2.070289 | Jxx_eff=0.1076 (true 0.1000) | Jyy_eff=0.1949 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2988 (true 0.3000) | hz_eff=0.9904 (true 1.0000)
# [NDE(t)] Step  141/500 | Loss=2.070286 | Jxx_eff=0.1072 (true 0.1000) | Jyy_eff=0.1951 (true 0.2000) | Jzz_eff=0.6983 (true 0.7000) | hx_eff=0.2986 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  142/500 | Loss=2.070285 | Jxx_eff=0.1069 (true 0.1000) | Jyy_eff=0.1956 (true 0.2000) | Jzz_eff=0.6983 (true 0.7000) | hx_eff=0.2982 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  143/500 | Loss=2.070282 | Jxx_eff=0.1069 (true 0.1000) | Jyy_eff=0.1962 (true 0.2000) | Jzz_eff=0.6984 (true 0.7000) | hx_eff=0.2977 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step  144/500 | Loss=2.070277 | Jxx_eff=0.1067 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6988 (true 0.7000) | hx_eff=0.2973 (true 0.3000) | hz_eff=0.9904 (true 1.0000)
# [NDE(t)] Step  145/500 | Loss=2.070278 | Jxx_eff=0.1065 (true 0.1000) | Jyy_eff=0.1968 (true 0.2000) | Jzz_eff=0.6989 (true 0.7000) | hx_eff=0.2972 (true 0.3000) | hz_eff=0.9903 (true 1.0000)
# [NDE(t)] Step  146/500 | Loss=2.070279 | Jxx_eff=0.1062 (true 0.1000) | Jyy_eff=0.1968 (true 0.2000) | Jzz_eff=0.6989 (true 0.7000) | hx_eff=0.2971 (true 0.3000) | hz_eff=0.9903 (true 1.0000)
# [NDE(t)] Step  147/500 | Loss=2.070278 | Jxx_eff=0.1059 (true 0.1000) | Jyy_eff=0.1968 (true 0.2000) | Jzz_eff=0.6989 (true 0.7000) | hx_eff=0.2972 (true 0.3000) | hz_eff=0.9904 (true 1.0000)
# [NDE(t)] Step  148/500 | Loss=2.070277 | Jxx_eff=0.1056 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6988 (true 0.7000) | hx_eff=0.2973 (true 0.3000) | hz_eff=0.9906 (true 1.0000)
# [NDE(t)] Step  149/500 | Loss=2.070277 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2974 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step  150/500 | Loss=2.070277 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2976 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  151/500 | Loss=2.070276 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1968 (true 0.2000) | Jzz_eff=0.6985 (true 0.7000) | hx_eff=0.2978 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  152/500 | Loss=2.070275 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1968 (true 0.2000) | Jzz_eff=0.6985 (true 0.7000) | hx_eff=0.2980 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  153/500 | Loss=2.070274 | Jxx_eff=0.1059 (true 0.1000) | Jyy_eff=0.1969 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2982 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step  154/500 | Loss=2.070274 | Jxx_eff=0.1061 (true 0.1000) | Jyy_eff=0.1969 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9907 (true 1.0000)
# [NDE(t)] Step  155/500 | Loss=2.070274 | Jxx_eff=0.1061 (true 0.1000) | Jyy_eff=0.1969 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9907 (true 1.0000)
# [NDE(t)] Step  156/500 | Loss=2.070274 | Jxx_eff=0.1061 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9907 (true 1.0000)
# [NDE(t)] Step  157/500 | Loss=2.070274 | Jxx_eff=0.1060 (true 0.1000) | Jyy_eff=0.1965 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step  158/500 | Loss=2.070273 | Jxx_eff=0.1059 (true 0.1000) | Jyy_eff=0.1964 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  159/500 | Loss=2.070273 | Jxx_eff=0.1058 (true 0.1000) | Jyy_eff=0.1962 (true 0.2000) | Jzz_eff=0.6985 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  160/500 | Loss=2.070273 | Jxx_eff=0.1058 (true 0.1000) | Jyy_eff=0.1962 (true 0.2000) | Jzz_eff=0.6985 (true 0.7000) | hx_eff=0.2982 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  161/500 | Loss=2.070272 | Jxx_eff=0.1059 (true 0.1000) | Jyy_eff=0.1962 (true 0.2000) | Jzz_eff=0.6985 (true 0.7000) | hx_eff=0.2981 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  162/500 | Loss=2.070272 | Jxx_eff=0.1060 (true 0.1000) | Jyy_eff=0.1962 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2980 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  163/500 | Loss=2.070272 | Jxx_eff=0.1061 (true 0.1000) | Jyy_eff=0.1963 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2979 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  164/500 | Loss=2.070272 | Jxx_eff=0.1062 (true 0.1000) | Jyy_eff=0.1963 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2979 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step  165/500 | Loss=2.070272 | Jxx_eff=0.1061 (true 0.1000) | Jyy_eff=0.1964 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2979 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step  166/500 | Loss=2.070271 | Jxx_eff=0.1061 (true 0.1000) | Jyy_eff=0.1964 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2979 (true 0.3000) | hz_eff=0.9908 (true 1.0000)
# [NDE(t)] Step  167/500 | Loss=2.070271 | Jxx_eff=0.1060 (true 0.1000) | Jyy_eff=0.1963 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2979 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  168/500 | Loss=2.070271 | Jxx_eff=0.1059 (true 0.1000) | Jyy_eff=0.1963 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2980 (true 0.3000) | hz_eff=0.9909 (true 1.0000)
# [NDE(t)] Step  169/500 | Loss=2.070271 | Jxx_eff=0.1059 (true 0.1000) | Jyy_eff=0.1963 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2980 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  170/500 | Loss=2.070271 | Jxx_eff=0.1058 (true 0.1000) | Jyy_eff=0.1963 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2981 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  171/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1963 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2982 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  172/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1964 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2982 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  173/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1964 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  174/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1964 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  175/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1965 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  176/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1966 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  177/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1966 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  178/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  179/500 | Loss=2.070270 | Jxx_eff=0.1057 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  180/500 | Loss=2.070270 | Jxx_eff=0.1056 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  181/500 | Loss=2.070269 | Jxx_eff=0.1056 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  182/500 | Loss=2.070269 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  183/500 | Loss=2.070269 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  184/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  185/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  186/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  187/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  188/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  189/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  190/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  191/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  192/500 | Loss=2.070269 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  193/500 | Loss=2.070269 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  194/500 | Loss=2.070268 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  195/500 | Loss=2.070268 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  196/500 | Loss=2.070268 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6987 (true 0.7000) | hx_eff=0.2983 (true 0.3000) | hz_eff=0.9910 (true 1.0000)
# [NDE(t)] Step  197/500 | Loss=2.070268 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  198/500 | Loss=2.070268 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  199/500 | Loss=2.070268 | Jxx_eff=0.1055 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  200/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  201/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  202/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  203/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  204/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  205/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  206/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  207/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  208/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  209/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  210/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  211/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2984 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  212/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [NDE(t)] Step  213/500 | Loss=2.070268 | Jxx_eff=0.1054 (true 0.1000) | Jyy_eff=0.1967 (true 0.2000) | Jzz_eff=0.6986 (true 0.7000) | hx_eff=0.2985 (true 0.3000) | hz_eff=0.9911 (true 1.0000)
# [EarlyStopping] Parando en step 213 porque la loss no mejora (min_delta=1e-05) en 50 iteraciones. Best=2.070272
# NDE Success rate: 0.9
# Errors (mean ± std): 0.04371054508428452 ± 0.10190063130550145

# %%
# time = 400 min
# save data for later analysis (opcional)
'''with open("robustness_nde.pkl", "wb") as f:
    pickle.dump(rob_nde, f)'''
# Out:
# Loaded NDE robustness data keys: dict_keys(['errors', 'final_loss', 'final_params', 'steps_used', 'success', 'success_threshold', 'success_rate'])
# Loaded NDE success rate: 0.9
# Loaded NDE errors (mean ± std): 0.04371054508428452 ± 0.10190063130550145

# %%
def plot_robustness_hist(results: dict, bins: int = 12, title_prefix: str = "Model"):
    errors = results["errors"]
    thr = results["success_threshold"]
    success_rate = results["success_rate"]

    # Histograma error relativo
    plt.figure()
    plt.hist(errors, bins=bins)
    plt.axvline(thr, linestyle="--", linewidth=2, label=f"success threshold = {thr}")
    plt.xlabel(r"Relative parameter error")
    plt.ylabel("Count")
    plt.title(f"{title_prefix} robustness\nsuccess rate = {success_rate*100:.1f}%")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()

    # Histograma loss final (compatible con ambos modelos)
    key = "final_nll" if "final_nll" in results else "final_loss"

    plt.figure()
    plt.hist(results[key], bins=bins)
    plt.xlabel("Final loss")
    plt.ylabel("Count")
    plt.title(f"{title_prefix} final loss distribution")
    plt.grid(alpha=0.3)
    plt.show()

# %%
# load data to check it worked
with open("robustness_nde.pkl", "rb") as f:
    loaded_rob_nde = pickle.load(f)
print("Loaded NDE robustness data keys:", loaded_rob_nde.keys())
print("Loaded NDE success rate:", loaded_rob_nde["success_rate"])
print("Loaded NDE errors (mean ± std):", loaded_rob_nde["errors"].mean(), "±", loaded_rob_nde["errors"].std())

plot_robustness_hist(loaded_rob_nde, bins=10, title_prefix="Neural ODE (loaded)")
# Out:
# Loaded NDE robustness data keys: dict_keys(['errors', 'final_loss', 'final_params', 'steps_used', 'success', 'success_threshold', 'success_rate'])
# Loaded NDE success rate: 0.9
# Loaded NDE errors (mean ± std): 0.04371054508428452 ± 0.10190063130550145
